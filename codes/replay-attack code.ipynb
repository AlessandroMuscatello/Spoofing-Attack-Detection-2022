# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We import all the main important **dependencies**

# %%
import random, os
import numpy as np
import tensorflow as tf
import cv2
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
from imutils import paths
from sklearn.model_selection import train_test_split
import pickle
import shutil


def tf_seed(seed=0):
  np.random.seed(seed)  # numpy seed
  tf.random.set_seed(seed)  # tensorflow seed
  random.seed(seed)  # random seed
  os.environ['TF_DETERMINISTIC_OPS'] = "1"
  os.environ['TF_CUDNN_DETERMINISM'] = "1"
  os.environ['PYTHONHASHSEED'] = str(seed)
  


tf_seed()

# %% [markdown]
# The main idea is to classify a **bonafide or attack** human face with a fast **CNN**, setting on the top of the network an **SSD** model, pretrained on a **ResNet**, that can extract faces from images.
#
# The network will have two main convolutional steps, in which we are going to extract deep features from the second phase. It uses in sequence **Conv2d + BatchNormalization** to learn faster, normalizing batch feature maps to avoid **overfitting**. However, this is why is important to set a right batch size and training data to avoid the opposite problem, then underfitting. The BatchNormalization, since this is a shallow network, won't have the so called vanishing gradient problem during the first training epochs.
#
# There are also, at the end of each phase, a Dropout layer. This is because it's important to learn as much details as possible to distinguish a "real or fake" person in front of a camera. So switching off weights during training randomly, will have the consequence to distribute better the learning of important features among all the weights.

# %% [markdown]
# # DEFINE NETWORK

# %% [markdown]
# ## Originary Network

# %%
def LiveNet(input_size):

  chan_dim=-1 #feature map channel

  #first convolutional phase
  input = tf.keras.layers.Input(input_size)
  x = tf.keras.layers.Conv2D(16, 3, activation = 'relu', padding = 'same')(input)
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.Conv2D(16, 3, activation = 'relu', padding = 'same')(x)
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
  x = tf.keras.layers.Dropout(0.25)(x)

  #second convolutional phase
  x = tf.keras.layers.Conv2D(32, 3, activation = 'relu', padding = 'same')(x)
  x = tf.keras.layers.BatchNormalization( axis=chan_dim)(x)
  x = tf.keras.layers.Conv2D(32, 3, activation = 'relu', padding = 'same')(x)

  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
  x = tf.keras.layers.Dropout(0.25)(x)

  #dense phase
  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(64, activation = 'relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)


  x = tf.keras.layers.Dropout(0.5)(x)  #to avoid overfitting 
  #softmax 
  output = tf.keras.layers.Dense(2, activation = 'softmax')(x)
 
  return tf.keras.models.Model(input, output)

# %% [markdown]
# ## AttackNet v2.1

# %%
def LiveNet(input_size):

  chan_dim=4 #feature map channel

  #first convolutional phase
  input = tf.keras.layers.Input(input_size)
  y = tf.keras.layers.Conv2D(16, 3, padding = 'same')(input)
  x = tf.keras.layers.LeakyReLU(alpha=0.2)(y)
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.Conv2D(16, 3, padding = 'same')(x)
  x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
  x = tf.keras.layers.Conv2D(16, 3, padding = 'same')(x)
  z = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
  x = tf.keras.layers.concatenate([y,z])
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
  x = tf.keras.layers.Dropout(0.25)(x)

  #second convolutional phase
  y = tf.keras.layers.Conv2D(32, 3, padding = 'same')(x)
  x = tf.keras.layers.LeakyReLU(alpha=0.2)(y)
  x = tf.keras.layers.BatchNormalization( axis=chan_dim)(x)
  x = tf.keras.layers.Conv2D(32, 3, padding = 'same')(x)
  x = tf.keras.layers.Conv2D(32, 3, padding = 'same')(x)
  z = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
  x = tf.keras.layers.concatenate([y,z])
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
  x = tf.keras.layers.Dropout(0.25)(x)

  #dense phase
  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(128, activation = 'tanh')(x)
  #x = BatchNormalization()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  #softmax 
  output = tf.keras.layers.Dense(2, activation = 'softmax')(x)
 
  return tf.keras.models.Model(input, output)

# %% [markdown]
# ## FINE-TUNING AttackNet V2.1
#
# We are going to fine-tune our model we trained on FIRST DATASET using AttackNet v2.1

# %%
def LiveNet(input=None):

  model=tf.keras.models.load_model(os.path.join(root_folder,"first_task_model.h5")) #that one that uses offline augmentation with 20 epochs
  

  # we freeze everything except the last 12 layers
  # we are freezing the first convolutional step

  # Freeze the first convolutional stage
  for layer in model.layers[:12]:
    layer.trainable = False  

 # model.summary()



  return model

# %% [markdown]
# # REPLAY-ATTACK DATASET

# %% [markdown]
# We define absolute paths that will be used.
#
# The dataset is the following: https://www.idiap.ch/en/dataset/replayattack
#
# I. Chingovska, A. Anjos, S. Marcel,"On the Effectiveness of Local Binary Patterns in Face Anti-spoofing"; IEEE BIOSIG, 2012.
# https://ieeexplore.ieee.org/document/6313548
# http://publications.idiap.ch/index.php/publications/show/2447
#
# <br><br>
# The Replay-Attack Database for face spoofing consists of 1300 video clips of photo and video attack attempts to 50 clients, under different lighting conditions. This Database was produced at the Idiap Research Institute, in Switzerland.
#
#
# ## Dataset Structure
#
# We got about 9k frames from almost all the images and videos of the original dataset, so in our case the dataset is organized in two main subdirectories: **attack**, **real**. The two directories **attack** and **real** contain images for attacks and bona fide presentations, respectively.
#
# ## Training and Validation Data
#
# The original dataset is already divided in **train**, **test** folders. We include in the training also images inside the **devel** folders.

# %% [markdown]
# ## Define Root Folders

# %%
root_folder="/content/drive/MyDrive/liveness_project/"


protoPath=os.path.join(root_folder,'face_detector/deploy.prototxt.txt')
modelPath = os.path.join(root_folder,
	"face_detector/res10_300x300_ssd_iter_140000.caffemodel")


face_confidence=0.75

Replay_Attack_extracted=os.path.join(root_folder,'dataset/training/Replay-Attack extracted/')




#we define where to save output detected faces and the corresponding depth
output_attack_training_folder=os.path.join(root_folder,'dataset/training/Replay_Attack/images/attack_training/')
output_attack_validation_folder=os.path.join(root_folder,'dataset/training/Replay_Attack/images/attack_validation/')

output_bonifade_training_folder=os.path.join(root_folder,'dataset/training/Replay_Attack/images/bonifade_training/')
output_bonifade_validation_folder=os.path.join(root_folder,'dataset/training/Replay_Attack/images/bonifade_validation/')


save_augmented_images =  os.path.join(root_folder,'dataset/training/Replay_Attack/augmented_images/') #output of online augmented images 
save_model_h5 = os.path.join(root_folder,'model_Replay_Attack.h5') 
save_labels = os.path.join(root_folder,'model_Replay_Attack_labels')
save_training_metrics_plot = os.path.join(root_folder,'Replay_Attack_plot.png')

output_np_training_array = os.path.join(root_folder,'Replay_Attack_training_array')



def get_folders(folder_types=["train"], image_type="attack"):

	final_folders=[]

	for folder_type in folder_types:

			init_folders=[]

			new_root=os.path.join(Replay_Attack_extracted, folder_type, image_type) #ex. train/real/

			
			if image_type=="attack": 
						init_folders.append(os.path.join(new_root, "fixed")) #ex. train/attack/fixed
						init_folders.append(os.path.join(new_root, "hand"))  #ex. train/attack/hand
			else:
						init_folders.append(new_root)
			

			for folder in init_folders:
					final_folders += [f.path for f in os.scandir(folder) if f.is_dir()]


	return final_folders


attack_folders_training = get_folders(["train","devel"], "attack")
attack_folders_validation = get_folders(["test"],"attack")

bonifade_folders_training = get_folders(["train","devel"], "real")
bonifade_folders_validation = get_folders(["test"], "real")

training_directories=[attack_folders_training, attack_folders_validation, bonifade_folders_training, bonifade_folders_validation]
output_directories=[output_attack_training_folder, output_attack_validation_folder, output_bonifade_training_folder, output_bonifade_validation_folder]


#create directories where to save images if they don't exist
for output_dir in output_directories:
	if not os.path.exists(output_dir): 
	  os.makedirs(output_dir)
	  print("created ",  output_dir)
	 
	 
print("Attack folders for training: " , attack_folders_training)
print("Attack folders for validation: " , attack_folders_validation)
print("Bonifade folders for training: " , bonifade_folders_training)
print("Bonifade folders for validation: " , bonifade_folders_validation)
# Out:
# Attack folders for training:  ['/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client001_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client001_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client001_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client001_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client002_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client002_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client002_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client002_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client004_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client004_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client004_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client004_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client006_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client006_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client006_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client006_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client007_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client007_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client007_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client007_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client008_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client008_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client008_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attack/fixed/attack_highdef_client008_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/attac ...
# Attack folders for validation:  ['/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client009_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client009_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client009_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client009_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client011_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client011_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client011_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client011_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client013_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client013_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client013_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client013_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client014_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client014_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client014_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client014_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client019_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client019_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client019_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client020_session01_highdef_photo_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client019_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client020_session01_highdef_video_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client020_session01_highdef_photo_controlled', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_client020_session01_highdef_video_adverse', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/attack/fixed/attack_highdef_ ...
# Bonifade folders for training:  ['/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client001_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client001_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client001_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client001_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client002_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client002_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client002_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client002_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client004_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client004_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client004_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client004_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client006_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client006_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client006_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client006_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client007_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client007_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client007_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client007_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client008_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client008_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client008_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client008_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client012_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client012_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client012_session01_webcam_authenticate_controlled_1', '/content/dri ...
# Bonifade folders for validation:  ['/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client104_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client104_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client106_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client106_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client106_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client106_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client107_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client107_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client107_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client107_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client109_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client109_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client109_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client109_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client112_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client112_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client112_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client112_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client115_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client115_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client115_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client115_session01_webcam_authenticate_controlled_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client117_session01_webcam_authenticate_adverse_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client117_session01_webcam_authenticate_adverse_2', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client117_session01_webcam_authenticate_controlled_1', '/content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client117_session01_webcam_authenticate_controlled_2']

# %% [markdown]
# # NETWORK PARAMETERS FOR TRAINING

# %%
final_x = 32
final_y = 32

n_channels = 3

dim = (final_x, final_y)

epochs=20
batch_size=256
init_learning_rate= 1e-4

#return normalized image
def resize_normalize_image(image, value=255):
  image=cv2.resize(image, dim)
  return (image)/np.max(image)

# %% [markdown]
# # FACE PROCESSING

# %% [markdown]
# ## Network to Detect Faces
#
# We define the SSD network that detects face inside an image.
#
# In this case, since we want to save in .pgm format, we convert image to grayscale before, otherwise `cv2.imwrite` won't work correctly.

# %%
#read ssd model to detect faces
net = cv2.dnn.readNetFromCaffe(protoPath, modelPath) 


# detect the most probable face, or all of detected face
# return coordinates of bounding box for each face and the face itself as a cv2 object
def detect_save_face(frame, output_path=None, multiple_output=False):

    (h, w) = frame.shape[:2]

    # we preprocess image normalizing each r-g-b channel subtracting the values in the last tuple
    blob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)), 1.0,
                                 (300, 300), (104.0, 177.0, 123.0))
    # pass the blob through the network and obtain the detections and
    # predictions
    net.setInput(blob)
    detections = net.forward()   #output => (1, 1, 20, [1, 0.9, .... ]   )
    faces = []
    coordinates=[]
    
    # ensure at least one face was found
    if len(detections) > 0:

       
        
        max_i=np.argmax(detections[0, 0, :, 2]) #this is the most probable detected face

        #if we want to output the most probable detected face or all the faces
        min_range = 0 if multiple_output==True else max_i 
        max_range = detections.shape[2] if multiple_output==True else max_i + 1

        for i in range(min_range, max_range):

          # we get the model confidence
          confidence = detections[0, 0, i, 2]

          if confidence >= face_confidence:
            # compute the (x, y)-coordinates of the bounding box for
            # the face and extract the face ROI
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # we save coordinates 
            coordinates.append(box.astype("int"))
            face = frame[startY:endY, startX:endX]

            #we save the face
            faces.append(face)
            

            try:
            
              #we save the image if output_path is defined
              if output_path is not None:
               # gray = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
                cv2.imwrite(output_path, face)
             
            except:
              print("error")
              pass

    return faces, coordinates

#frame_mask_output = [mask_genuine_folder, mask_fake_folder]

#return file name given a path
def get_file_name(path):
    base = os.path.basename(path)
    return os.path.splitext(base)[0]

#return file extension given a path
def get_file_type(path): 
    base = os.path.basename(path)
    return os.path.splitext(base)[1] # ex. .png, .jpg

print(get_file_type("file.png"))
# Out:
# .png

# %% [markdown]
# ## Extract Faces from Images
#
# We are going to take videos or images from our dataset. For each frame will be detected **one** face, and this one will be saved to the output folders defined before. The code reserves the possibility for the user to define also a mask for each image. In this case, the detected face will be also "cropped" from the mask.

# %%
max_images_per_folder=20000000000 #we want to take a maximum number of images for training since limited hardware resources
shuffle_seed = 20


#for each training input directory, search for color image
#for each color image (RGB), we take the corresponding align_to_depth and depth images 
#for each image and depth, we detect one face
def take_images():
    directory_counter = 0
    file_counter = 0

    for main_list in training_directories:

          folder_file_counter=0

          d_index=0

          print("we're on array %d/%d" % (directory_counter + 1, len(training_directories)))


          for directory in main_list:

            d_index+=1

            print("we're on %s" % directory)

          # files = [file for file in os.listdir(directory[0])]

            list_images = [file for file in os.listdir(directory)]

            #we shuffle training data since we just take a limited number of images
            random.Random(20).shuffle(list_images)

            print("found %d images for folder n. %d/%d" % (len(list_images), d_index, len(main_list)))

            for file in list_images:

                file_path=os.path.join(directory, file)

                if folder_file_counter > max_images_per_folder:
                  break

              #  file_path = os.path.join(directory, file)
                
                color=cv2.imread(file_path)
                              
                detect_save_face(color,  (os.path.join(output_directories[directory_counter], "%s%s" % (
                        "frame_%d" % file_counter, get_file_type(file_path)))))
                
                    
                folder_file_counter+=1

                print("save face detected on image n. %d, for folder n. %d" % (file_counter, directory_counter + 1))


                file_counter += 1

          directory_counter += 1


take_images()
# Out:
# Streaming output truncated to the last 5000 lines.
# save face detected on image n. 24158, for folder n. 3
# save face detected on image n. 24159, for folder n. 3
# save face detected on image n. 24160, for folder n. 3
# save face detected on image n. 24161, for folder n. 3
# save face detected on image n. 24162, for folder n. 3
# save face detected on image n. 24163, for folder n. 3
# save face detected on image n. 24164, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client007_session01_webcam_authenticate_adverse_2
# found 37 images for folder n. 19/120
# save face detected on image n. 24165, for folder n. 3
# save face detected on image n. 24166, for folder n. 3
# save face detected on image n. 24167, for folder n. 3
# save face detected on image n. 24168, for folder n. 3
# save face detected on image n. 24169, for folder n. 3
# save face detected on image n. 24170, for folder n. 3
# save face detected on image n. 24171, for folder n. 3
# save face detected on image n. 24172, for folder n. 3
# save face detected on image n. 24173, for folder n. 3
# save face detected on image n. 24174, for folder n. 3
# save face detected on image n. 24175, for folder n. 3
# save face detected on image n. 24176, for folder n. 3
# save face detected on image n. 24177, for folder n. 3
# save face detected on image n. 24178, for folder n. 3
# save face detected on image n. 24179, for folder n. 3
# save face detected on image n. 24180, for folder n. 3
# save face detected on image n. 24181, for folder n. 3
# save face detected on image n. 24182, for folder n. 3
# save face detected on image n. 24183, for folder n. 3
# save face detected on image n. 24184, for folder n. 3
# save face detected on image n. 24185, for folder n. 3
# save face detected on image n. 24186, for folder n. 3
# save face detected on image n. 24187, for folder n. 3
# save face detected on image n. 24188, for folder n. 3
# save face detected on image n. 24189, for folder n. 3
# save face detected on image n. 24190, for folder n. 3
# save face detected on image n. 24191, for folder n. 3
# save face detected on image n. 24192, for folder n. 3
# save face detected on image n. 24193, for folder n. 3
# save face detected on image n. 24194, for folder n. 3
# save face detected on image n. 24195, for folder n. 3
# save face detected on image n. 24196, for folder n. 3
# save face detected on image n. 24197, for folder n. 3
# save face detected on image n. 24198, for folder n. 3
# save face detected on image n. 24199, for folder n. 3
# save face detected on image n. 24200, for folder n. 3
# save face detected on image n. 24201, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client007_session01_webcam_authenticate_controlled_2
# found 37 images for folder n. 20/120
# save face detected on image n. 24202, for folder n. 3
# save face detected on image n. 24203, for folder n. 3
# save face detected on image n. 24204, for folder n. 3
# save face detected on image n. 24205, for folder n. 3
# save face detected on image n. 24206, for folder n. 3
# save face detected on image n. 24207, for folder n. 3
# save face detected on image n. 24208, for folder n. 3
# save face detected on image n. 24209, for folder n. 3
# save face detected on image n. 24210, for folder n. 3
# save face detected on image n. 24211, for folder n. 3
# save face detected on image n. 24212, for folder n. 3
# save face detected on image n. 24213, for folder n. 3
# save face detected on image n. 24214, for folder n. 3
# save face detected on image n. 24215, for folder n. 3
# save face detected on image n. 24216, for folder n. 3
# save face detected on image n. 24217, for folder n. 3
# save face detected on image n. 24218, for folder n. 3
# save face detected on image n. 24219, for folder n. 3
# save face detected on image n. 24220, for folder n. 3
# save face detected on image n. 24221, for folder n. 3
# save face detected on image n. 24222, for folder n. 3
# save face detected on image n. 24223, for folder n. 3
# save face detected on image n. 24224, for folder n. 3
# save face detected on image n. 24225, for folder n. 3
# save face detected on image n. 24226, for folder n. 3
# save face detected on image n. 24227, for folder n. 3
# save face detected on image n. 24228, for folder n. 3
# save face detected on image n. 24229, for folder n. 3
# save face detected on image n. 24230, for folder n. 3
# save face detected on image n. 24231, for folder n. 3
# save face detected on image n. 24232, for folder n. 3
# save face detected on image n. 24233, for folder n. 3
# save face detected on image n. 24234, for folder n. 3
# save face detected on image n. 24235, for folder n. 3
# save face detected on image n. 24236, for folder n. 3
# save face detected on image n. 24237, for folder n. 3
# save face detected on image n. 24238, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client008_session01_webcam_authenticate_adverse_1
# found 37 images for folder n. 21/120
# save face detected on image n. 24239, for folder n. 3
# save face detected on image n. 24240, for folder n. 3
# save face detected on image n. 24241, for folder n. 3
# save face detected on image n. 24242, for folder n. 3
# save face detected on image n. 24243, for folder n. 3
# save face detected on image n. 24244, for folder n. 3
# save face detected on image n. 24245, for folder n. 3
# save face detected on image n. 24246, for folder n. 3
# save face detected on image n. 24247, for folder n. 3
# save face detected on image n. 24248, for folder n. 3
# save face detected on image n. 24249, for folder n. 3
# save face detected on image n. 24250, for folder n. 3
# save face detected on image n. 24251, for folder n. 3
# save face detected on image n. 24252, for folder n. 3
# save face detected on image n. 24253, for folder n. 3
# save face detected on image n. 24254, for folder n. 3
# save face detected on image n. 24255, for folder n. 3
# save face detected on image n. 24256, for folder n. 3
# save face detected on image n. 24257, for folder n. 3
# save face detected on image n. 24258, for folder n. 3
# save face detected on image n. 24259, for folder n. 3
# save face detected on image n. 24260, for folder n. 3
# save face detected on image n. 24261, for folder n. 3
# save face detected on image n. 24262, for folder n. 3
# save face detected on image n. 24263, for folder n. 3
# save face detected on image n. 24264, for folder n. 3
# save face detected on image n. 24265, for folder n. 3
# save face detected on image n. 24266, for folder n. 3
# save face detected on image n. 24267, for folder n. 3
# save face detected on image n. 24268, for folder n. 3
# save face detected on image n. 24269, for folder n. 3
# save face detected on image n. 24270, for folder n. 3
# save face detected on image n. 24271, for folder n. 3
# save face detected on image n. 24272, for folder n. 3
# save face detected on image n. 24273, for folder n. 3
# save face detected on image n. 24274, for folder n. 3
# save face detected on image n. 24275, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client008_session01_webcam_authenticate_adverse_2
# found 37 images for folder n. 22/120
# save face detected on image n. 24276, for folder n. 3
# save face detected on image n. 24277, for folder n. 3
# save face detected on image n. 24278, for folder n. 3
# save face detected on image n. 24279, for folder n. 3
# save face detected on image n. 24280, for folder n. 3
# save face detected on image n. 24281, for folder n. 3
# save face detected on image n. 24282, for folder n. 3
# save face detected on image n. 24283, for folder n. 3
# save face detected on image n. 24284, for folder n. 3
# save face detected on image n. 24285, for folder n. 3
# save face detected on image n. 24286, for folder n. 3
# save face detected on image n. 24287, for folder n. 3
# save face detected on image n. 24288, for folder n. 3
# save face detected on image n. 24289, for folder n. 3
# save face detected on image n. 24290, for folder n. 3
# save face detected on image n. 24291, for folder n. 3
# save face detected on image n. 24292, for folder n. 3
# save face detected on image n. 24293, for folder n. 3
# save face detected on image n. 24294, for folder n. 3
# save face detected on image n. 24295, for folder n. 3
# save face detected on image n. 24296, for folder n. 3
# save face detected on image n. 24297, for folder n. 3
# save face detected on image n. 24298, for folder n. 3
# save face detected on image n. 24299, for folder n. 3
# save face detected on image n. 24300, for folder n. 3
# save face detected on image n. 24301, for folder n. 3
# save face detected on image n. 24302, for folder n. 3
# save face detected on image n. 24303, for folder n. 3
# save face detected on image n. 24304, for folder n. 3
# save face detected on image n. 24305, for folder n. 3
# save face detected on image n. 24306, for folder n. 3
# save face detected on image n. 24307, for folder n. 3
# save face detected on image n. 24308, for folder n. 3
# save face detected on image n. 24309, for folder n. 3
# save face detected on image n. 24310, for folder n. 3
# save face detected on image n. 24311, for folder n. 3
# save face detected on image n. 24312, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client008_session01_webcam_authenticate_controlled_1
# found 37 images for folder n. 23/120
# save face detected on image n. 24313, for folder n. 3
# save face detected on image n. 24314, for folder n. 3
# save face detected on image n. 24315, for folder n. 3
# save face detected on image n. 24316, for folder n. 3
# save face detected on image n. 24317, for folder n. 3
# save face detected on image n. 24318, for folder n. 3
# save face detected on image n. 24319, for folder n. 3
# save face detected on image n. 24320, for folder n. 3
# save face detected on image n. 24321, for folder n. 3
# save face detected on image n. 24322, for folder n. 3
# save face detected on image n. 24323, for folder n. 3
# save face detected on image n. 24324, for folder n. 3
# save face detected on image n. 24325, for folder n. 3
# save face detected on image n. 24326, for folder n. 3
# save face detected on image n. 24327, for folder n. 3
# save face detected on image n. 24328, for folder n. 3
# save face detected on image n. 24329, for folder n. 3
# save face detected on image n. 24330, for folder n. 3
# save face detected on image n. 24331, for folder n. 3
# save face detected on image n. 24332, for folder n. 3
# save face detected on image n. 24333, for folder n. 3
# save face detected on image n. 24334, for folder n. 3
# save face detected on image n. 24335, for folder n. 3
# save face detected on image n. 24336, for folder n. 3
# save face detected on image n. 24337, for folder n. 3
# save face detected on image n. 24338, for folder n. 3
# save face detected on image n. 24339, for folder n. 3
# save face detected on image n. 24340, for folder n. 3
# save face detected on image n. 24341, for folder n. 3
# save face detected on image n. 24342, for folder n. 3
# save face detected on image n. 24343, for folder n. 3
# save face detected on image n. 24344, for folder n. 3
# save face detected on image n. 24345, for folder n. 3
# save face detected on image n. 24346, for folder n. 3
# save face detected on image n. 24347, for folder n. 3
# save face detected on image n. 24348, for folder n. 3
# save face detected on image n. 24349, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client008_session01_webcam_authenticate_controlled_2
# found 37 images for folder n. 24/120
# save face detected on image n. 24350, for folder n. 3
# save face detected on image n. 24351, for folder n. 3
# save face detected on image n. 24352, for folder n. 3
# save face detected on image n. 24353, for folder n. 3
# save face detected on image n. 24354, for folder n. 3
# save face detected on image n. 24355, for folder n. 3
# save face detected on image n. 24356, for folder n. 3
# save face detected on image n. 24357, for folder n. 3
# save face detected on image n. 24358, for folder n. 3
# save face detected on image n. 24359, for folder n. 3
# save face detected on image n. 24360, for folder n. 3
# save face detected on image n. 24361, for folder n. 3
# save face detected on image n. 24362, for folder n. 3
# save face detected on image n. 24363, for folder n. 3
# save face detected on image n. 24364, for folder n. 3
# save face detected on image n. 24365, for folder n. 3
# save face detected on image n. 24366, for folder n. 3
# save face detected on image n. 24367, for folder n. 3
# save face detected on image n. 24368, for folder n. 3
# save face detected on image n. 24369, for folder n. 3
# save face detected on image n. 24370, for folder n. 3
# save face detected on image n. 24371, for folder n. 3
# save face detected on image n. 24372, for folder n. 3
# save face detected on image n. 24373, for folder n. 3
# save face detected on image n. 24374, for folder n. 3
# save face detected on image n. 24375, for folder n. 3
# save face detected on image n. 24376, for folder n. 3
# save face detected on image n. 24377, for folder n. 3
# save face detected on image n. 24378, for folder n. 3
# save face detected on image n. 24379, for folder n. 3
# save face detected on image n. 24380, for folder n. 3
# save face detected on image n. 24381, for folder n. 3
# save face detected on image n. 24382, for folder n. 3
# save face detected on image n. 24383, for folder n. 3
# save face detected on image n. 24384, for folder n. 3
# save face detected on image n. 24385, for folder n. 3
# save face detected on image n. 24386, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client012_session01_webcam_authenticate_adverse_1
# found 37 images for folder n. 25/120
# save face detected on image n. 24387, for folder n. 3
# save face detected on image n. 24388, for folder n. 3
# save face detected on image n. 24389, for folder n. 3
# save face detected on image n. 24390, for folder n. 3
# save face detected on image n. 24391, for folder n. 3
# save face detected on image n. 24392, for folder n. 3
# save face detected on image n. 24393, for folder n. 3
# save face detected on image n. 24394, for folder n. 3
# save face detected on image n. 24395, for folder n. 3
# save face detected on image n. 24396, for folder n. 3
# save face detected on image n. 24397, for folder n. 3
# save face detected on image n. 24398, for folder n. 3
# save face detected on image n. 24399, for folder n. 3
# save face detected on image n. 24400, for folder n. 3
# save face detected on image n. 24401, for folder n. 3
# save face detected on image n. 24402, for folder n. 3
# save face detected on image n. 24403, for folder n. 3
# save face detected on image n. 24404, for folder n. 3
# save face detected on image n. 24405, for folder n. 3
# save face detected on image n. 24406, for folder n. 3
# save face detected on image n. 24407, for folder n. 3
# save face detected on image n. 24408, for folder n. 3
# save face detected on image n. 24409, for folder n. 3
# save face detected on image n. 24410, for folder n. 3
# save face detected on image n. 24411, for folder n. 3
# save face detected on image n. 24412, for folder n. 3
# save face detected on image n. 24413, for folder n. 3
# save face detected on image n. 24414, for folder n. 3
# save face detected on image n. 24415, for folder n. 3
# save face detected on image n. 24416, for folder n. 3
# save face detected on image n. 24417, for folder n. 3
# save face detected on image n. 24418, for folder n. 3
# save face detected on image n. 24419, for folder n. 3
# save face detected on image n. 24420, for folder n. 3
# save face detected on image n. 24421, for folder n. 3
# save face detected on image n. 24422, for folder n. 3
# save face detected on image n. 24423, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client012_session01_webcam_authenticate_adverse_2
# found 37 images for folder n. 26/120
# save face detected on image n. 24424, for folder n. 3
# save face detected on image n. 24425, for folder n. 3
# save face detected on image n. 24426, for folder n. 3
# save face detected on image n. 24427, for folder n. 3
# save face detected on image n. 24428, for folder n. 3
# save face detected on image n. 24429, for folder n. 3
# save face detected on image n. 24430, for folder n. 3
# save face detected on image n. 24431, for folder n. 3
# save face detected on image n. 24432, for folder n. 3
# save face detected on image n. 24433, for folder n. 3
# save face detected on image n. 24434, for folder n. 3
# save face detected on image n. 24435, for folder n. 3
# save face detected on image n. 24436, for folder n. 3
# save face detected on image n. 24437, for folder n. 3
# save face detected on image n. 24438, for folder n. 3
# save face detected on image n. 24439, for folder n. 3
# save face detected on image n. 24440, for folder n. 3
# save face detected on image n. 24441, for folder n. 3
# save face detected on image n. 24442, for folder n. 3
# save face detected on image n. 24443, for folder n. 3
# save face detected on image n. 24444, for folder n. 3
# save face detected on image n. 24445, for folder n. 3
# save face detected on image n. 24446, for folder n. 3
# save face detected on image n. 24447, for folder n. 3
# save face detected on image n. 24448, for folder n. 3
# save face detected on image n. 24449, for folder n. 3
# save face detected on image n. 24450, for folder n. 3
# save face detected on image n. 24451, for folder n. 3
# save face detected on image n. 24452, for folder n. 3
# save face detected on image n. 24453, for folder n. 3
# save face detected on image n. 24454, for folder n. 3
# save face detected on image n. 24455, for folder n. 3
# save face detected on image n. 24456, for folder n. 3
# save face detected on image n. 24457, for folder n. 3
# save face detected on image n. 24458, for folder n. 3
# save face detected on image n. 24459, for folder n. 3
# save face detected on image n. 24460, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client012_session01_webcam_authenticate_controlled_1
# found 37 images for folder n. 27/120
# save face detected on image n. 24461, for folder n. 3
# save face detected on image n. 24462, for folder n. 3
# save face detected on image n. 24463, for folder n. 3
# save face detected on image n. 24464, for folder n. 3
# save face detected on image n. 24465, for folder n. 3
# save face detected on image n. 24466, for folder n. 3
# save face detected on image n. 24467, for folder n. 3
# save face detected on image n. 24468, for folder n. 3
# save face detected on image n. 24469, for folder n. 3
# save face detected on image n. 24470, for folder n. 3
# save face detected on image n. 24471, for folder n. 3
# save face detected on image n. 24472, for folder n. 3
# save face detected on image n. 24473, for folder n. 3
# save face detected on image n. 24474, for folder n. 3
# save face detected on image n. 24475, for folder n. 3
# save face detected on image n. 24476, for folder n. 3
# save face detected on image n. 24477, for folder n. 3
# save face detected on image n. 24478, for folder n. 3
# save face detected on image n. 24479, for folder n. 3
# save face detected on image n. 24480, for folder n. 3
# save face detected on image n. 24481, for folder n. 3
# save face detected on image n. 24482, for folder n. 3
# save face detected on image n. 24483, for folder n. 3
# save face detected on image n. 24484, for folder n. 3
# save face detected on image n. 24485, for folder n. 3
# save face detected on image n. 24486, for folder n. 3
# save face detected on image n. 24487, for folder n. 3
# save face detected on image n. 24488, for folder n. 3
# save face detected on image n. 24489, for folder n. 3
# save face detected on image n. 24490, for folder n. 3
# save face detected on image n. 24491, for folder n. 3
# save face detected on image n. 24492, for folder n. 3
# save face detected on image n. 24493, for folder n. 3
# save face detected on image n. 24494, for folder n. 3
# save face detected on image n. 24495, for folder n. 3
# save face detected on image n. 24496, for folder n. 3
# save face detected on image n. 24497, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client012_session01_webcam_authenticate_controlled_2
# found 37 images for folder n. 28/120
# save face detected on image n. 24498, for folder n. 3
# save face detected on image n. 24499, for folder n. 3
# save face detected on image n. 24500, for folder n. 3
# save face detected on image n. 24501, for folder n. 3
# save face detected on image n. 24502, for folder n. 3
# save face detected on image n. 24503, for folder n. 3
# save face detected on image n. 24504, for folder n. 3
# save face detected on image n. 24505, for folder n. 3
# save face detected on image n. 24506, for folder n. 3
# save face detected on image n. 24507, for folder n. 3
# save face detected on image n. 24508, for folder n. 3
# save face detected on image n. 24509, for folder n. 3
# save face detected on image n. 24510, for folder n. 3
# save face detected on image n. 24511, for folder n. 3
# save face detected on image n. 24512, for folder n. 3
# save face detected on image n. 24513, for folder n. 3
# save face detected on image n. 24514, for folder n. 3
# save face detected on image n. 24515, for folder n. 3
# save face detected on image n. 24516, for folder n. 3
# save face detected on image n. 24517, for folder n. 3
# save face detected on image n. 24518, for folder n. 3
# save face detected on image n. 24519, for folder n. 3
# save face detected on image n. 24520, for folder n. 3
# save face detected on image n. 24521, for folder n. 3
# save face detected on image n. 24522, for folder n. 3
# save face detected on image n. 24523, for folder n. 3
# save face detected on image n. 24524, for folder n. 3
# save face detected on image n. 24525, for folder n. 3
# save face detected on image n. 24526, for folder n. 3
# save face detected on image n. 24527, for folder n. 3
# save face detected on image n. 24528, for folder n. 3
# save face detected on image n. 24529, for folder n. 3
# save face detected on image n. 24530, for folder n. 3
# save face detected on image n. 24531, for folder n. 3
# save face detected on image n. 24532, for folder n. 3
# save face detected on image n. 24533, for folder n. 3
# save face detected on image n. 24534, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client016_session01_webcam_authenticate_adverse_1
# found 37 images for folder n. 29/120
# save face detected on image n. 24535, for folder n. 3
# save face detected on image n. 24536, for folder n. 3
# save face detected on image n. 24537, for folder n. 3
# save face detected on image n. 24538, for folder n. 3
# save face detected on image n. 24539, for folder n. 3
# save face detected on image n. 24540, for folder n. 3
# save face detected on image n. 24541, for folder n. 3
# save face detected on image n. 24542, for folder n. 3
# save face detected on image n. 24543, for folder n. 3
# save face detected on image n. 24544, for folder n. 3
# save face detected on image n. 24545, for folder n. 3
# save face detected on image n. 24546, for folder n. 3
# save face detected on image n. 24547, for folder n. 3
# save face detected on image n. 24548, for folder n. 3
# save face detected on image n. 24549, for folder n. 3
# save face detected on image n. 24550, for folder n. 3
# save face detected on image n. 24551, for folder n. 3
# save face detected on image n. 24552, for folder n. 3
# save face detected on image n. 24553, for folder n. 3
# save face detected on image n. 24554, for folder n. 3
# save face detected on image n. 24555, for folder n. 3
# save face detected on image n. 24556, for folder n. 3
# save face detected on image n. 24557, for folder n. 3
# save face detected on image n. 24558, for folder n. 3
# save face detected on image n. 24559, for folder n. 3
# save face detected on image n. 24560, for folder n. 3
# save face detected on image n. 24561, for folder n. 3
# save face detected on image n. 24562, for folder n. 3
# save face detected on image n. 24563, for folder n. 3
# save face detected on image n. 24564, for folder n. 3
# save face detected on image n. 24565, for folder n. 3
# save face detected on image n. 24566, for folder n. 3
# save face detected on image n. 24567, for folder n. 3
# save face detected on image n. 24568, for folder n. 3
# save face detected on image n. 24569, for folder n. 3
# save face detected on image n. 24570, for folder n. 3
# save face detected on image n. 24571, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client016_session01_webcam_authenticate_adverse_2
# found 37 images for folder n. 30/120
# save face detected on image n. 24572, for folder n. 3
# save face detected on image n. 24573, for folder n. 3
# save face detected on image n. 24574, for folder n. 3
# save face detected on image n. 24575, for folder n. 3
# save face detected on image n. 24576, for folder n. 3
# save face detected on image n. 24577, for folder n. 3
# save face detected on image n. 24578, for folder n. 3
# save face detected on image n. 24579, for folder n. 3
# save face detected on image n. 24580, for folder n. 3
# save face detected on image n. 24581, for folder n. 3
# save face detected on image n. 24582, for folder n. 3
# save face detected on image n. 24583, for folder n. 3
# save face detected on image n. 24584, for folder n. 3
# save face detected on image n. 24585, for folder n. 3
# save face detected on image n. 24586, for folder n. 3
# save face detected on image n. 24587, for folder n. 3
# save face detected on image n. 24588, for folder n. 3
# save face detected on image n. 24589, for folder n. 3
# save face detected on image n. 24590, for folder n. 3
# save face detected on image n. 24591, for folder n. 3
# save face detected on image n. 24592, for folder n. 3
# save face detected on image n. 24593, for folder n. 3
# save face detected on image n. 24594, for folder n. 3
# save face detected on image n. 24595, for folder n. 3
# save face detected on image n. 24596, for folder n. 3
# save face detected on image n. 24597, for folder n. 3
# save face detected on image n. 24598, for folder n. 3
# save face detected on image n. 24599, for folder n. 3
# save face detected on image n. 24600, for folder n. 3
# save face detected on image n. 24601, for folder n. 3
# save face detected on image n. 24602, for folder n. 3
# save face detected on image n. 24603, for folder n. 3
# save face detected on image n. 24604, for folder n. 3
# save face detected on image n. 24605, for folder n. 3
# save face detected on image n. 24606, for folder n. 3
# save face detected on image n. 24607, for folder n. 3
# save face detected on image n. 24608, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client016_session01_webcam_authenticate_controlled_1
# found 37 images for folder n. 31/120
# save face detected on image n. 24609, for folder n. 3
# save face detected on image n. 24610, for folder n. 3
# save face detected on image n. 24611, for folder n. 3
# save face detected on image n. 24612, for folder n. 3
# save face detected on image n. 24613, for folder n. 3
# save face detected on image n. 24614, for folder n. 3
# save face detected on image n. 24615, for folder n. 3
# save face detected on image n. 24616, for folder n. 3
# save face detected on image n. 24617, for folder n. 3
# save face detected on image n. 24618, for folder n. 3
# save face detected on image n. 24619, for folder n. 3
# save face detected on image n. 24620, for folder n. 3
# save face detected on image n. 24621, for folder n. 3
# save face detected on image n. 24622, for folder n. 3
# save face detected on image n. 24623, for folder n. 3
# save face detected on image n. 24624, for folder n. 3
# save face detected on image n. 24625, for folder n. 3
# save face detected on image n. 24626, for folder n. 3
# save face detected on image n. 24627, for folder n. 3
# save face detected on image n. 24628, for folder n. 3
# save face detected on image n. 24629, for folder n. 3
# save face detected on image n. 24630, for folder n. 3
# save face detected on image n. 24631, for folder n. 3
# save face detected on image n. 24632, for folder n. 3
# save face detected on image n. 24633, for folder n. 3
# save face detected on image n. 24634, for folder n. 3
# save face detected on image n. 24635, for folder n. 3
# save face detected on image n. 24636, for folder n. 3
# save face detected on image n. 24637, for folder n. 3
# save face detected on image n. 24638, for folder n. 3
# save face detected on image n. 24639, for folder n. 3
# save face detected on image n. 24640, for folder n. 3
# save face detected on image n. 24641, for folder n. 3
# save face detected on image n. 24642, for folder n. 3
# save face detected on image n. 24643, for folder n. 3
# save face detected on image n. 24644, for folder n. 3
# save face detected on image n. 24645, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client016_session01_webcam_authenticate_controlled_2
# found 37 images for folder n. 32/120
# save face detected on image n. 24646, for folder n. 3
# save face detected on image n. 24647, for folder n. 3
# save face detected on image n. 24648, for folder n. 3
# save face detected on image n. 24649, for folder n. 3
# save face detected on image n. 24650, for folder n. 3
# save face detected on image n. 24651, for folder n. 3
# save face detected on image n. 24652, for folder n. 3
# save face detected on image n. 24653, for folder n. 3
# save face detected on image n. 24654, for folder n. 3
# save face detected on image n. 24655, for folder n. 3
# save face detected on image n. 24656, for folder n. 3
# save face detected on image n. 24657, for folder n. 3
# save face detected on image n. 24658, for folder n. 3
# save face detected on image n. 24659, for folder n. 3
# save face detected on image n. 24660, for folder n. 3
# save face detected on image n. 24661, for folder n. 3
# save face detected on image n. 24662, for folder n. 3
# save face detected on image n. 24663, for folder n. 3
# save face detected on image n. 24664, for folder n. 3
# save face detected on image n. 24665, for folder n. 3
# save face detected on image n. 24666, for folder n. 3
# save face detected on image n. 24667, for folder n. 3
# save face detected on image n. 24668, for folder n. 3
# save face detected on image n. 24669, for folder n. 3
# save face detected on image n. 24670, for folder n. 3
# save face detected on image n. 24671, for folder n. 3
# save face detected on image n. 24672, for folder n. 3
# save face detected on image n. 24673, for folder n. 3
# save face detected on image n. 24674, for folder n. 3
# save face detected on image n. 24675, for folder n. 3
# save face detected on image n. 24676, for folder n. 3
# save face detected on image n. 24677, for folder n. 3
# save face detected on image n. 24678, for folder n. 3
# save face detected on image n. 24679, for folder n. 3
# save face detected on image n. 24680, for folder n. 3
# save face detected on image n. 24681, for folder n. 3
# save face detected on image n. 24682, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client018_session01_webcam_authenticate_adverse_1
# found 37 images for folder n. 33/120
# save face detected on image n. 24683, for folder n. 3
# save face detected on image n. 24684, for folder n. 3
# save face detected on image n. 24685, for folder n. 3
# save face detected on image n. 24686, for folder n. 3
# save face detected on image n. 24687, for folder n. 3
# save face detected on image n. 24688, for folder n. 3
# save face detected on image n. 24689, for folder n. 3
# save face detected on image n. 24690, for folder n. 3
# save face detected on image n. 24691, for folder n. 3
# save face detected on image n. 24692, for folder n. 3
# save face detected on image n. 24693, for folder n. 3
# save face detected on image n. 24694, for folder n. 3
# save face detected on image n. 24695, for folder n. 3
# save face detected on image n. 24696, for folder n. 3
# save face detected on image n. 24697, for folder n. 3
# save face detected on image n. 24698, for folder n. 3
# save face detected on image n. 24699, for folder n. 3
# save face detected on image n. 24700, for folder n. 3
# save face detected on image n. 24701, for folder n. 3
# save face detected on image n. 24702, for folder n. 3
# save face detected on image n. 24703, for folder n. 3
# save face detected on image n. 24704, for folder n. 3
# save face detected on image n. 24705, for folder n. 3
# save face detected on image n. 24706, for folder n. 3
# save face detected on image n. 24707, for folder n. 3
# save face detected on image n. 24708, for folder n. 3
# save face detected on image n. 24709, for folder n. 3
# save face detected on image n. 24710, for folder n. 3
# save face detected on image n. 24711, for folder n. 3
# save face detected on image n. 24712, for folder n. 3
# save face detected on image n. 24713, for folder n. 3
# save face detected on image n. 24714, for folder n. 3
# save face detected on image n. 24715, for folder n. 3
# save face detected on image n. 24716, for folder n. 3
# save face detected on image n. 24717, for folder n. 3
# save face detected on image n. 24718, for folder n. 3
# save face detected on image n. 24719, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client018_session01_webcam_authenticate_controlled_1
# found 37 images for folder n. 34/120
# save face detected on image n. 24720, for folder n. 3
# save face detected on image n. 24721, for folder n. 3
# save face detected on image n. 24722, for folder n. 3
# save face detected on image n. 24723, for folder n. 3
# save face detected on image n. 24724, for folder n. 3
# save face detected on image n. 24725, for folder n. 3
# save face detected on image n. 24726, for folder n. 3
# save face detected on image n. 24727, for folder n. 3
# save face detected on image n. 24728, for folder n. 3
# save face detected on image n. 24729, for folder n. 3
# save face detected on image n. 24730, for folder n. 3
# save face detected on image n. 24731, for folder n. 3
# save face detected on image n. 24732, for folder n. 3
# save face detected on image n. 24733, for folder n. 3
# save face detected on image n. 24734, for folder n. 3
# save face detected on image n. 24735, for folder n. 3
# save face detected on image n. 24736, for folder n. 3
# save face detected on image n. 24737, for folder n. 3
# save face detected on image n. 24738, for folder n. 3
# save face detected on image n. 24739, for folder n. 3
# save face detected on image n. 24740, for folder n. 3
# save face detected on image n. 24741, for folder n. 3
# save face detected on image n. 24742, for folder n. 3
# save face detected on image n. 24743, for folder n. 3
# save face detected on image n. 24744, for folder n. 3
# save face detected on image n. 24745, for folder n. 3
# save face detected on image n. 24746, for folder n. 3
# save face detected on image n. 24747, for folder n. 3
# save face detected on image n. 24748, for folder n. 3
# save face detected on image n. 24749, for folder n. 3
# save face detected on image n. 24750, for folder n. 3
# save face detected on image n. 24751, for folder n. 3
# save face detected on image n. 24752, for folder n. 3
# save face detected on image n. 24753, for folder n. 3
# save face detected on image n. 24754, for folder n. 3
# save face detected on image n. 24755, for folder n. 3
# save face detected on image n. 24756, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client018_session01_webcam_authenticate_adverse_2
# found 37 images for folder n. 35/120
# save face detected on image n. 24757, for folder n. 3
# save face detected on image n. 24758, for folder n. 3
# save face detected on image n. 24759, for folder n. 3
# save face detected on image n. 24760, for folder n. 3
# save face detected on image n. 24761, for folder n. 3
# save face detected on image n. 24762, for folder n. 3
# save face detected on image n. 24763, for folder n. 3
# save face detected on image n. 24764, for folder n. 3
# save face detected on image n. 24765, for folder n. 3
# save face detected on image n. 24766, for folder n. 3
# save face detected on image n. 24767, for folder n. 3
# save face detected on image n. 24768, for folder n. 3
# save face detected on image n. 24769, for folder n. 3
# save face detected on image n. 24770, for folder n. 3
# save face detected on image n. 24771, for folder n. 3
# save face detected on image n. 24772, for folder n. 3
# save face detected on image n. 24773, for folder n. 3
# save face detected on image n. 24774, for folder n. 3
# save face detected on image n. 24775, for folder n. 3
# save face detected on image n. 24776, for folder n. 3
# save face detected on image n. 24777, for folder n. 3
# save face detected on image n. 24778, for folder n. 3
# save face detected on image n. 24779, for folder n. 3
# save face detected on image n. 24780, for folder n. 3
# save face detected on image n. 24781, for folder n. 3
# save face detected on image n. 24782, for folder n. 3
# save face detected on image n. 24783, for folder n. 3
# save face detected on image n. 24784, for folder n. 3
# save face detected on image n. 24785, for folder n. 3
# save face detected on image n. 24786, for folder n. 3
# save face detected on image n. 24787, for folder n. 3
# save face detected on image n. 24788, for folder n. 3
# save face detected on image n. 24789, for folder n. 3
# save face detected on image n. 24790, for folder n. 3
# save face detected on image n. 24791, for folder n. 3
# save face detected on image n. 24792, for folder n. 3
# save face detected on image n. 24793, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client018_session01_webcam_authenticate_controlled_2
# found 37 images for folder n. 36/120
# save face detected on image n. 24794, for folder n. 3
# save face detected on image n. 24795, for folder n. 3
# save face detected on image n. 24796, for folder n. 3
# save face detected on image n. 24797, for folder n. 3
# save face detected on image n. 24798, for folder n. 3
# save face detected on image n. 24799, for folder n. 3
# save face detected on image n. 24800, for folder n. 3
# save face detected on image n. 24801, for folder n. 3
# save face detected on image n. 24802, for folder n. 3
# save face detected on image n. 24803, for folder n. 3
# save face detected on image n. 24804, for folder n. 3
# save face detected on image n. 24805, for folder n. 3
# save face detected on image n. 24806, for folder n. 3
# save face detected on image n. 24807, for folder n. 3
# save face detected on image n. 24808, for folder n. 3
# save face detected on image n. 24809, for folder n. 3
# save face detected on image n. 24810, for folder n. 3
# save face detected on image n. 24811, for folder n. 3
# save face detected on image n. 24812, for folder n. 3
# save face detected on image n. 24813, for folder n. 3
# save face detected on image n. 24814, for folder n. 3
# save face detected on image n. 24815, for folder n. 3
# save face detected on image n. 24816, for folder n. 3
# save face detected on image n. 24817, for folder n. 3
# save face detected on image n. 24818, for folder n. 3
# save face detected on image n. 24819, for folder n. 3
# save face detected on image n. 24820, for folder n. 3
# save face detected on image n. 24821, for folder n. 3
# save face detected on image n. 24822, for folder n. 3
# save face detected on image n. 24823, for folder n. 3
# save face detected on image n. 24824, for folder n. 3
# save face detected on image n. 24825, for folder n. 3
# save face detected on image n. 24826, for folder n. 3
# save face detected on image n. 24827, for folder n. 3
# save face detected on image n. 24828, for folder n. 3
# save face detected on image n. 24829, for folder n. 3
# save face detected on image n. 24830, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client025_session01_webcam_authenticate_adverse_2
# found 37 images for folder n. 37/120
# save face detected on image n. 24831, for folder n. 3
# save face detected on image n. 24832, for folder n. 3
# save face detected on image n. 24833, for folder n. 3
# save face detected on image n. 24834, for folder n. 3
# save face detected on image n. 24835, for folder n. 3
# save face detected on image n. 24836, for folder n. 3
# save face detected on image n. 24837, for folder n. 3
# save face detected on image n. 24838, for folder n. 3
# save face detected on image n. 24839, for folder n. 3
# save face detected on image n. 24840, for folder n. 3
# save face detected on image n. 24841, for folder n. 3
# save face detected on image n. 24842, for folder n. 3
# save face detected on image n. 24843, for folder n. 3
# save face detected on image n. 24844, for folder n. 3
# save face detected on image n. 24845, for folder n. 3
# save face detected on image n. 24846, for folder n. 3
# save face detected on image n. 24847, for folder n. 3
# save face detected on image n. 24848, for folder n. 3
# save face detected on image n. 24849, for folder n. 3
# save face detected on image n. 24850, for folder n. 3
# save face detected on image n. 24851, for folder n. 3
# save face detected on image n. 24852, for folder n. 3
# save face detected on image n. 24853, for folder n. 3
# save face detected on image n. 24854, for folder n. 3
# save face detected on image n. 24855, for folder n. 3
# save face detected on image n. 24856, for folder n. 3
# save face detected on image n. 24857, for folder n. 3
# save face detected on image n. 24858, for folder n. 3
# save face detected on image n. 24859, for folder n. 3
# save face detected on image n. 24860, for folder n. 3
# save face detected on image n. 24861, for folder n. 3
# save face detected on image n. 24862, for folder n. 3
# save face detected on image n. 24863, for folder n. 3
# save face detected on image n. 24864, for folder n. 3
# save face detected on image n. 24865, for folder n. 3
# save face detected on image n. 24866, for folder n. 3
# save face detected on image n. 24867, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client025_session01_webcam_authenticate_adverse_1
# found 37 images for folder n. 38/120
# save face detected on image n. 24868, for folder n. 3
# save face detected on image n. 24869, for folder n. 3
# save face detected on image n. 24870, for folder n. 3
# save face detected on image n. 24871, for folder n. 3
# save face detected on image n. 24872, for folder n. 3
# save face detected on image n. 24873, for folder n. 3
# save face detected on image n. 24874, for folder n. 3
# save face detected on image n. 24875, for folder n. 3
# save face detected on image n. 24876, for folder n. 3
# save face detected on image n. 24877, for folder n. 3
# save face detected on image n. 24878, for folder n. 3
# save face detected on image n. 24879, for folder n. 3
# save face detected on image n. 24880, for folder n. 3
# save face detected on image n. 24881, for folder n. 3
# save face detected on image n. 24882, for folder n. 3
# save face detected on image n. 24883, for folder n. 3
# save face detected on image n. 24884, for folder n. 3
# save face detected on image n. 24885, for folder n. 3
# save face detected on image n. 24886, for folder n. 3
# save face detected on image n. 24887, for folder n. 3
# save face detected on image n. 24888, for folder n. 3
# save face detected on image n. 24889, for folder n. 3
# save face detected on image n. 24890, for folder n. 3
# save face detected on image n. 24891, for folder n. 3
# save face detected on image n. 24892, for folder n. 3
# save face detected on image n. 24893, for folder n. 3
# save face detected on image n. 24894, for folder n. 3
# save face detected on image n. 24895, for folder n. 3
# save face detected on image n. 24896, for folder n. 3
# save face detected on image n. 24897, for folder n. 3
# save face detected on image n. 24898, for folder n. 3
# save face detected on image n. 24899, for folder n. 3
# save face detected on image n. 24900, for folder n. 3
# save face detected on image n. 24901, for folder n. 3
# save face detected on image n. 24902, for folder n. 3
# save face detected on image n. 24903, for folder n. 3
# save face detected on image n. 24904, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client025_session01_webcam_authenticate_controlled_2
# found 37 images for folder n. 39/120
# save face detected on image n. 24905, for folder n. 3
# save face detected on image n. 24906, for folder n. 3
# save face detected on image n. 24907, for folder n. 3
# save face detected on image n. 24908, for folder n. 3
# save face detected on image n. 24909, for folder n. 3
# save face detected on image n. 24910, for folder n. 3
# save face detected on image n. 24911, for folder n. 3
# save face detected on image n. 24912, for folder n. 3
# save face detected on image n. 24913, for folder n. 3
# save face detected on image n. 24914, for folder n. 3
# save face detected on image n. 24915, for folder n. 3
# save face detected on image n. 24916, for folder n. 3
# save face detected on image n. 24917, for folder n. 3
# save face detected on image n. 24918, for folder n. 3
# save face detected on image n. 24919, for folder n. 3
# save face detected on image n. 24920, for folder n. 3
# save face detected on image n. 24921, for folder n. 3
# save face detected on image n. 24922, for folder n. 3
# save face detected on image n. 24923, for folder n. 3
# save face detected on image n. 24924, for folder n. 3
# save face detected on image n. 24925, for folder n. 3
# save face detected on image n. 24926, for folder n. 3
# save face detected on image n. 24927, for folder n. 3
# save face detected on image n. 24928, for folder n. 3
# save face detected on image n. 24929, for folder n. 3
# save face detected on image n. 24930, for folder n. 3
# save face detected on image n. 24931, for folder n. 3
# save face detected on image n. 24932, for folder n. 3
# save face detected on image n. 24933, for folder n. 3
# save face detected on image n. 24934, for folder n. 3
# save face detected on image n. 24935, for folder n. 3
# save face detected on image n. 24936, for folder n. 3
# save face detected on image n. 24937, for folder n. 3
# save face detected on image n. 24938, for folder n. 3
# save face detected on image n. 24939, for folder n. 3
# save face detected on image n. 24940, for folder n. 3
# save face detected on image n. 24941, for folder n. 3
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/train/real/client025_session01_webcam_authenticate_controlled_1
# found 37 images for folder n. 40/120
# save face detected on image n. 24942, for folder n. 3
# save face detected on image n. 24943, for folder n. 3
# save face detected on image n. 24944, for folder n. 3
# save face detected on image n. 24945, for folder n. 3
# save face detected on image n. 24946, for folder n. 3
# save face detected on image n. 24947, for folder n. 3
# save face detected on image n. 24948, for folder n. 3
# save face detected on image n. 24949, for folder n. 3
# save face detected on image n. 24950, for folder n. 3
# save face detected on image n. 24951, for folder n. 3
# save face detected on image n. 24952, for folder n. 3
# save face detected on image n. 24953, for folder n. 3
# save face detected on image n. 24954, for folder n. 3
# save face detected on image n. 24955, for folder n. 3
# save face detected on image n. 24956, for folder n. 3
# save face detected on image n. 24957, for folder n. 3
# save face detected on image n. 24958, for folder n. 3
# save face detected on image n. 24959, for folder n. 3
# save face detected on image n. 24960, for folder n. 3
# save face detected on image n. 24961, for folder n. 3
# save face detected on image n. 24962, for folder n. 3
# save face detected on image n. 24963, for folder n. 3
# save face detected on image n. 24964, for folder n. 3
# save face detected on image n. 24965, for folder n. 3
# save face detected on image n. 24966, for folder n. 3
# save face detected on image n. 24967, for folder n. 3
# ...
# save face detected on image n. 28630, for folder n. 4
# save face detected on image n. 28631, for folder n. 4
# save face detected on image n. 28632, for folder n. 4
# save face detected on image n. 28633, for folder n. 4
# save face detected on image n. 28634, for folder n. 4
# save face detected on image n. 28635, for folder n. 4
# save face detected on image n. 28636, for folder n. 4
# save face detected on image n. 28637, for folder n. 4
# save face detected on image n. 28638, for folder n. 4
# save face detected on image n. 28639, for folder n. 4
# save face detected on image n. 28640, for folder n. 4
# save face detected on image n. 28641, for folder n. 4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client115_session01_webcam_authenticate_adverse_1
# found 37 images for folder n. 20/26
# save face detected on image n. 28642, for folder n. 4
# save face detected on image n. 28643, for folder n. 4
# save face detected on image n. 28644, for folder n. 4
# save face detected on image n. 28645, for folder n. 4
# save face detected on image n. 28646, for folder n. 4
# save face detected on image n. 28647, for folder n. 4
# save face detected on image n. 28648, for folder n. 4
# save face detected on image n. 28649, for folder n. 4
# save face detected on image n. 28650, for folder n. 4
# save face detected on image n. 28651, for folder n. 4
# save face detected on image n. 28652, for folder n. 4
# save face detected on image n. 28653, for folder n. 4
# save face detected on image n. 28654, for folder n. 4
# save face detected on image n. 28655, for folder n. 4
# save face detected on image n. 28656, for folder n. 4
# save face detected on image n. 28657, for folder n. 4
# save face detected on image n. 28658, for folder n. 4
# save face detected on image n. 28659, for folder n. 4
# save face detected on image n. 28660, for folder n. 4
# save face detected on image n. 28661, for folder n. 4
# save face detected on image n. 28662, for folder n. 4
# save face detected on image n. 28663, for folder n. 4
# save face detected on image n. 28664, for folder n. 4
# save face detected on image n. 28665, for folder n. 4
# save face detected on image n. 28666, for folder n. 4
# save face detected on image n. 28667, for folder n. 4
# save face detected on image n. 28668, for folder n. 4
# save face detected on image n. 28669, for folder n. 4
# save face detected on image n. 28670, for folder n. 4
# save face detected on image n. 28671, for folder n. 4
# save face detected on image n. 28672, for folder n. 4
# save face detected on image n. 28673, for folder n. 4
# save face detected on image n. 28674, for folder n. 4
# save face detected on image n. 28675, for folder n. 4
# save face detected on image n. 28676, for folder n. 4
# save face detected on image n. 28677, for folder n. 4
# save face detected on image n. 28678, for folder n. 4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client115_session01_webcam_authenticate_controlled_1
# found 37 images for folder n. 21/26
# save face detected on image n. 28679, for folder n. 4
# save face detected on image n. 28680, for folder n. 4
# save face detected on image n. 28681, for folder n. 4
# save face detected on image n. 28682, for folder n. 4
# save face detected on image n. 28683, for folder n. 4
# save face detected on image n. 28684, for folder n. 4
# save face detected on image n. 28685, for folder n. 4
# save face detected on image n. 28686, for folder n. 4
# save face detected on image n. 28687, for folder n. 4
# save face detected on image n. 28688, for folder n. 4
# save face detected on image n. 28689, for folder n. 4
# save face detected on image n. 28690, for folder n. 4
# save face detected on image n. 28691, for folder n. 4
# save face detected on image n. 28692, for folder n. 4
# save face detected on image n. 28693, for folder n. 4
# save face detected on image n. 28694, for folder n. 4
# save face detected on image n. 28695, for folder n. 4
# save face detected on image n. 28696, for folder n. 4
# save face detected on image n. 28697, for folder n. 4
# save face detected on image n. 28698, for folder n. 4
# save face detected on image n. 28699, for folder n. 4
# save face detected on image n. 28700, for folder n. 4
# save face detected on image n. 28701, for folder n. 4
# save face detected on image n. 28702, for folder n. 4
# save face detected on image n. 28703, for folder n. 4
# save face detected on image n. 28704, for folder n. 4
# save face detected on image n. 28705, for folder n. 4
# save face detected on image n. 28706, for folder n. 4
# save face detected on image n. 28707, for folder n. 4
# save face detected on image n. 28708, for folder n. 4
# save face detected on image n. 28709, for folder n. 4
# save face detected on image n. 28710, for folder n. 4
# save face detected on image n. 28711, for folder n. 4
# save face detected on image n. 28712, for folder n. 4
# save face detected on image n. 28713, for folder n. 4
# save face detected on image n. 28714, for folder n. 4
# save face detected on image n. 28715, for folder n. 4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client115_session01_webcam_authenticate_controlled_2
# found 37 images for folder n. 22/26
# save face detected on image n. 28716, for folder n. 4
# save face detected on image n. 28717, for folder n. 4
# save face detected on image n. 28718, for folder n. 4
# save face detected on image n. 28719, for folder n. 4
# save face detected on image n. 28720, for folder n. 4
# save face detected on image n. 28721, for folder n. 4
# save face detected on image n. 28722, for folder n. 4
# save face detected on image n. 28723, for folder n. 4
# save face detected on image n. 28724, for folder n. 4
# save face detected on image n. 28725, for folder n. 4
# save face detected on image n. 28726, for folder n. 4
# save face detected on image n. 28727, for folder n. 4
# save face detected on image n. 28728, for folder n. 4
# save face detected on image n. 28729, for folder n. 4
# save face detected on image n. 28730, for folder n. 4
# save face detected on image n. 28731, for folder n. 4
# save face detected on image n. 28732, for folder n. 4
# save face detected on image n. 28733, for folder n. 4
# save face detected on image n. 28734, for folder n. 4
# save face detected on image n. 28735, for folder n. 4
# save face detected on image n. 28736, for folder n. 4
# save face detected on image n. 28737, for folder n. 4
# save face detected on image n. 28738, for folder n. 4
# save face detected on image n. 28739, for folder n. 4
# save face detected on image n. 28740, for folder n. 4
# save face detected on image n. 28741, for folder n. 4
# save face detected on image n. 28742, for folder n. 4
# save face detected on image n. 28743, for folder n. 4
# save face detected on image n. 28744, for folder n. 4
# save face detected on image n. 28745, for folder n. 4
# save face detected on image n. 28746, for folder n. 4
# save face detected on image n. 28747, for folder n. 4
# save face detected on image n. 28748, for folder n. 4
# save face detected on image n. 28749, for folder n. 4
# save face detected on image n. 28750, for folder n. 4
# save face detected on image n. 28751, for folder n. 4
# save face detected on image n. 28752, for folder n. 4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client117_session01_webcam_authenticate_adverse_1
# found 37 images for folder n. 23/26
# save face detected on image n. 28753, for folder n. 4
# save face detected on image n. 28754, for folder n. 4
# save face detected on image n. 28755, for folder n. 4
# save face detected on image n. 28756, for folder n. 4
# save face detected on image n. 28757, for folder n. 4
# save face detected on image n. 28758, for folder n. 4
# save face detected on image n. 28759, for folder n. 4
# save face detected on image n. 28760, for folder n. 4
# save face detected on image n. 28761, for folder n. 4
# save face detected on image n. 28762, for folder n. 4
# save face detected on image n. 28763, for folder n. 4
# save face detected on image n. 28764, for folder n. 4
# save face detected on image n. 28765, for folder n. 4
# save face detected on image n. 28766, for folder n. 4
# save face detected on image n. 28767, for folder n. 4
# save face detected on image n. 28768, for folder n. 4
# save face detected on image n. 28769, for folder n. 4
# save face detected on image n. 28770, for folder n. 4
# save face detected on image n. 28771, for folder n. 4
# save face detected on image n. 28772, for folder n. 4
# save face detected on image n. 28773, for folder n. 4
# save face detected on image n. 28774, for folder n. 4
# save face detected on image n. 28775, for folder n. 4
# save face detected on image n. 28776, for folder n. 4
# save face detected on image n. 28777, for folder n. 4
# save face detected on image n. 28778, for folder n. 4
# save face detected on image n. 28779, for folder n. 4
# save face detected on image n. 28780, for folder n. 4
# save face detected on image n. 28781, for folder n. 4
# save face detected on image n. 28782, for folder n. 4
# save face detected on image n. 28783, for folder n. 4
# save face detected on image n. 28784, for folder n. 4
# save face detected on image n. 28785, for folder n. 4
# save face detected on image n. 28786, for folder n. 4
# save face detected on image n. 28787, for folder n. 4
# save face detected on image n. 28788, for folder n. 4
# save face detected on image n. 28789, for folder n. 4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client117_session01_webcam_authenticate_adverse_2
# found 37 images for folder n. 24/26
# save face detected on image n. 28790, for folder n. 4
# save face detected on image n. 28791, for folder n. 4
# save face detected on image n. 28792, for folder n. 4
# save face detected on image n. 28793, for folder n. 4
# save face detected on image n. 28794, for folder n. 4
# save face detected on image n. 28795, for folder n. 4
# save face detected on image n. 28796, for folder n. 4
# save face detected on image n. 28797, for folder n. 4
# save face detected on image n. 28798, for folder n. 4
# save face detected on image n. 28799, for folder n. 4
# save face detected on image n. 28800, for folder n. 4
# save face detected on image n. 28801, for folder n. 4
# save face detected on image n. 28802, for folder n. 4
# save face detected on image n. 28803, for folder n. 4
# save face detected on image n. 28804, for folder n. 4
# save face detected on image n. 28805, for folder n. 4
# save face detected on image n. 28806, for folder n. 4
# save face detected on image n. 28807, for folder n. 4
# save face detected on image n. 28808, for folder n. 4
# save face detected on image n. 28809, for folder n. 4
# save face detected on image n. 28810, for folder n. 4
# save face detected on image n. 28811, for folder n. 4
# save face detected on image n. 28812, for folder n. 4
# save face detected on image n. 28813, for folder n. 4
# save face detected on image n. 28814, for folder n. 4
# save face detected on image n. 28815, for folder n. 4
# save face detected on image n. 28816, for folder n. 4
# save face detected on image n. 28817, for folder n. 4
# save face detected on image n. 28818, for folder n. 4
# save face detected on image n. 28819, for folder n. 4
# save face detected on image n. 28820, for folder n. 4
# save face detected on image n. 28821, for folder n. 4
# save face detected on image n. 28822, for folder n. 4
# save face detected on image n. 28823, for folder n. 4
# save face detected on image n. 28824, for folder n. 4
# save face detected on image n. 28825, for folder n. 4
# save face detected on image n. 28826, for folder n. 4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client117_session01_webcam_authenticate_controlled_1
# found 37 images for folder n. 25/26
# save face detected on image n. 28827, for folder n. 4
# save face detected on image n. 28828, for folder n. 4
# save face detected on image n. 28829, for folder n. 4
# save face detected on image n. 28830, for folder n. 4
# save face detected on image n. 28831, for folder n. 4
# save face detected on image n. 28832, for folder n. 4
# save face detected on image n. 28833, for folder n. 4
# save face detected on image n. 28834, for folder n. 4
# save face detected on image n. 28835, for folder n. 4
# save face detected on image n. 28836, for folder n. 4
# save face detected on image n. 28837, for folder n. 4
# save face detected on image n. 28838, for folder n. 4
# save face detected on image n. 28839, for folder n. 4
# save face detected on image n. 28840, for folder n. 4
# save face detected on image n. 28841, for folder n. 4
# save face detected on image n. 28842, for folder n. 4
# save face detected on image n. 28843, for folder n. 4
# save face detected on image n. 28844, for folder n. 4
# save face detected on image n. 28845, for folder n. 4
# save face detected on image n. 28846, for folder n. 4
# save face detected on image n. 28847, for folder n. 4
# save face detected on image n. 28848, for folder n. 4
# save face detected on image n. 28849, for folder n. 4
# save face detected on image n. 28850, for folder n. 4
# save face detected on image n. 28851, for folder n. 4
# save face detected on image n. 28852, for folder n. 4
# save face detected on image n. 28853, for folder n. 4
# save face detected on image n. 28854, for folder n. 4
# save face detected on image n. 28855, for folder n. 4
# save face detected on image n. 28856, for folder n. 4
# save face detected on image n. 28857, for folder n. 4
# save face detected on image n. 28858, for folder n. 4
# save face detected on image n. 28859, for folder n. 4
# save face detected on image n. 28860, for folder n. 4
# save face detected on image n. 28861, for folder n. 4
# save face detected on image n. 28862, for folder n. 4
# save face detected on image n. 28863, for folder n. 4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/Replay-Attack extracted/test/real/client117_session01_webcam_authenticate_controlled_2
# found 37 images for folder n. 26/26
# save face detected on image n. 28864, for folder n. 4
# save face detected on image n. 28865, for folder n. 4
# save face detected on image n. 28866, for folder n. 4
# save face detected on image n. 28867, for folder n. 4
# save face detected on image n. 28868, for folder n. 4
# save face detected on image n. 28869, for folder n. 4
# save face detected on image n. 28870, for folder n. 4
# save face detected on image n. 28871, for folder n. 4
# save face detected on image n. 28872, for folder n. 4
# save face detected on image n. 28873, for folder n. 4
# save face detected on image n. 28874, for folder n. 4
# save face detected on image n. 28875, for folder n. 4
# save face detected on image n. 28876, for folder n. 4
# save face detected on image n. 28877, for folder n. 4
# save face detected on image n. 28878, for folder n. 4
# save face detected on image n. 28879, for folder n. 4
# save face detected on image n. 28880, for folder n. 4
# save face detected on image n. 28881, for folder n. 4
# save face detected on image n. 28882, for folder n. 4
# save face detected on image n. 28883, for folder n. 4
# save face detected on image n. 28884, for folder n. 4
# save face detected on image n. 28885, for folder n. 4
# save face detected on image n. 28886, for folder n. 4
# save face detected on image n. 28887, for folder n. 4
# save face detected on image n. 28888, for folder n. 4
# save face detected on image n. 28889, for folder n. 4
# save face detected on image n. 28890, for folder n. 4
# save face detected on image n. 28891, for folder n. 4
# save face detected on image n. 28892, for folder n. 4
# save face detected on image n. 28893, for folder n. 4
# save face detected on image n. 28894, for folder n. 4
# save face detected on image n. 28895, for folder n. 4
# save face detected on image n. 28896, for folder n. 4
# save face detected on image n. 28897, for folder n. 4
# save face detected on image n. 28898, for folder n. 4
# save face detected on image n. 28899, for folder n. 4
# save face detected on image n. 28900, for folder n. 4

# %% [markdown]
# # TRAINING SECTION

# %% [markdown]
# ## Get Training and Validation Data
#
# For each directory where we saved detected faces, we are going to create two arrays: images, that will be concatenated with the depth mask, **by default**, and labels (0 for bonafide, 1 for attackers)

# %%
def get_images(directories, balance_dataset=True, undersampling=False):

    image_list = []
    label_list = []

    classes = 0

    images_per_class=[]

    tf_seed()

    #for each input directory
    for i in directories:

        list_images = [f for f in os.listdir(i) if os.path.isfile(os.path.join(i, f))]

        images_number = len(list_images)

        random.Random(20).shuffle(list_images)



        print("n %d" % images_number)

        #if we use undersampling
        if undersampling:
          images_number = images_number if ((len(images_per_class) == 0) or (images_number <= images_per_class[-1]))  else images_per_class[-1]
        
        
        # to fill tensors we inizialise them
        X = np.empty((images_number, final_x, final_y, n_channels))

        L = np.empty((images_number))

        ipp = 0

        for im_name in list_images:
            
            im=os.path.join(i, im_name)


            # to get "balanced dataset" using undersampling method
            if (balance_dataset and undersampling) and len(images_per_class)  and ipp == images_per_class[-1]:
                break

            image = cv2.imread(im)
            image=resize_normalize_image(image)

          
                

            X[ipp, ..., :3] = image # each original image is rgb
            L[ipp] = classes  # 0 for real, 1 for fake for binary classification

            ipp += 1
        
        # check if the current class has lower images than the before
        # in this case we undersample the majority class randomly removing elements
        # we will have a balanced dataset: same images for all the classes

        if balance_dataset and undersampling:
            if len(images_per_class) and ipp < images_per_class[-1]:
            
              left_shift = 0

              for i in range(0, len(images_per_class)):

                  diff = images_per_class[i] - ipp

                  for j in range(0, diff):
                      random_index = np.random.randint(left_shift, images_per_class[i] - j)
                      image_list.pop(random_index)
                      label_list.pop(random_index)
                    #  print(random_index)

                  left_shift += images_per_class[i] - diff

        if undersampling or balance_dataset==False:
              for image in X:
                image_list.append(image)

              for label in L:
                label_list.append(label)
        else:
              image_array=[]
              label_array=[]
            
              for image in X:
                image_array.append(image)

              image_list.append(np.array(image_array, dtype="float"))

             
              for label in L:
                label_array.append(label)

              label_list.append(label_array)

              #[[2k], [1k]]
        
        if undersampling or balance_dataset==False:
            images_per_class.append(ipp)
        else:
            images_per_class.append(images_number)

        classes += 1

    #offline augmentation
    if balance_dataset and undersampling==False:

      
         max=np.max((images_per_class)) #[4k,3k,2k,1k]

         for j in range(0, len(images_per_class)):  #[[4k], [4k], [4k], [4k]]
            if images_per_class[j] < max:
              diff=max - images_per_class[j] #how many images to generate

              image_array=image_list[j]   #[3k]
              label_array=label_list[j]   #[3k]

              new_image_array=[]
             

              #use ImageDataGenerator 
              offline_generator = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20, zoom_range=0.15,
                       	width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
	                       horizontal_flip=True, fill_mode="constant")


              offline_generator=offline_generator.flow(image_array, batch_size=1, seed = 2)

              #generate the reamining images respect the majority class, to balance the dataset
              generated_images=0
              while generated_images < diff:
                     
                  for i in range(0,len(offline_generator)):
                        if generated_images == diff:
                          break
                        batch= next(offline_generator)
                        # print(batch.shape)
                        #print(new_image_array.shape)
                        new_image_array.append(batch[0])
                        
                        label_array.append(j)

                      
                        generated_images += 1

            
     
              image_list[j]=np.append(image_list[j], new_image_array, axis=0)


         # image_list and label_list were of type [[...], [...]] for attack and bonafide classes
         # we need a final array of type [image1,image2,...] for images and [0,1,...] for labels

         new_image_list= np.empty((0, final_x, final_y, n_channels))
         new_label_list=[]


         for class_value_array in image_list:
           new_image_list = np.vstack((new_image_list,class_value_array))

         for class_value_array in label_list:
           new_label_list += class_value_array

         image_list = new_image_list
         label_list = new_label_list

         print(image_list.shape)
         print(len(label_list))
         
        # im_show(new_image_list[2]) # we can show up an image 
      
        
    #create the one-hot encoded vector: [0 1], [1 0]
    le = LabelEncoder()
    labels = le.fit_transform(label_list)
    labels = tf.keras.utils.to_categorical(labels, 2)

    if type(image_list) is np.ndarray:
      return image_list, labels, le

    return  np.array(image_list, dtype="float"), labels, le



read_from_np_array = True


## WE CAN SAVE NUMPY RESULTS AND REUSE THEM LATER ##

if read_from_np_array:
      (trainX, testX, trainY, testY) = pickle.loads(open(output_np_training_array, "rb").read())
      le = pickle.loads(open(save_labels, "rb").read())

## WE ARE GOING TO GET THE TRAIN AND VALIDATION DATASETS, AND WE SAVE THE NUMPY ARRAYS ##
else:
      
      trainX, trainY, label_encoder = get_images([output_bonifade_training_folder, output_attack_training_folder], undersampling=True)

     
      #will be ignored if we set split_randomly_training_and_validation variable to True
      testX, testY, _ = get_images([output_bonifade_validation_folder, output_attack_validation_folder], undersampling=True,balance_dataset=True)


      #save model labels 
      f = open(save_labels, "wb")
      f.write(pickle.dumps(label_encoder))
      f.close()

      #save results
      pickle.dump((trainX, testX, trainY, testY), open(output_np_training_array, 'wb'))


 
print("Shape training: ", trainX.shape)
print("Shape validation: ", testX.shape)
# Out:
# Shape training:  (8880, 32, 32, 3)
# Shape validation:  (1924, 32, 32, 3)

# %% [markdown]
# ## Augmentation Online

# %%
augmentation_online=True



#the random seed for online augmentation
generator_seed=10

 
if augmentation_online:
		#online augmentation of training images
		aug_training = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20,
zoom_range=0.15,
width_shift_range=0.1, height_shift_range=0.1, shear_range=0.15,
horizontal_flip=True, fill_mode="constant")
	#	aug_training=tf.keras.preprocessing.image.ImageDataGenerator()

		#aug_training = tf.keras.preprocessing.image.ImageDataGenerator()


		# output an endless Iterator of batches
		# shuffle images, so the first generated batch is from batch_size random training images

		train_generator=aug_training.flow(trainX, trainY, batch_size=batch_size, shuffle=True, seed=generator_seed)


		# will be equal to np.ceil(len(train(X))/batch_size)
		# notice: if len(trainX) / batch_size is a float value, the last batch will contain less images than batch_size value
		print("lenght training batches ", len(train_generator))
		print("lenght training data ", len(trainX))
		print("lenght validation data ", len(testX))

		# we could use also a validation_generator, without augment images
		# this "trick" could be done for set up a valdation batch size on model.fit().. then at the end of an epoch, each batch will be validated

		#aug_validation=ImageDataGenerator()
		#validation_generator=aug_validation.flow(testX, testY, batch_size=batch_size, shuffle=False, seed=1)
# Out:
# lenght training batches  35
# lenght training data  8880
# lenght validation data  1924

# %% [markdown]
# We can output the generator images organized in batches

# %%
# we generate batch_size images, beginning from the first batch
batchx, batchy = next(train_generator)
for i in range(batchx.shape[0]):
    fig, (ax1) = plt.subplots(1) 
    ax1.set_title('image')  
    ax1.imshow(batchx[i][:,:,0], cmap='gray')
    print("Label-%d:"%i, np.argmax(batchy[i]))


train_generator.reset() #once an epoch ends, this function will be called to reset data

# we generate exactly len(trainX) - batch_size images beginning from the first batch, since we have reset the train_generator on the line before
for i in range(0,len(train_generator) - 1):
 break # remove to see all training augmented images for an epoch
 batchx, batchy = next(train_generator)
 for i in range(batchx.shape[0]):
    fig, (ax1) = plt.subplots(1) 
    ax1.set_title('image')  
    ax1.imshow(batchx[i][:,:,0], cmap='gray')
    print("Label-%d:"%i, batchy[i][0])

# %% [markdown]
# ## OFFLINE AUGMENTATION (optional)

# %% [markdown]
# For each image in the training set, we're going to augment the image itself and we add it to the training. So if we have 2k images for the training, the final length of the dataset will be 4k.

# %%
augmentation_online=False

generator_seed=10
     

if not augmentation_online:


  to_augment=len(trainY) 

  #print(to_augment)
  # to fill tensors we inizialise them
  X = np.empty((to_augment, final_x, final_y, n_channels), dtype="float")

  L = np.empty((to_augment), dtype="int")

  #use ImageDataGenerator 
  offline_generator = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20, zoom_range=0.25,
		 	    width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
			 horizontal_flip=True, fill_mode="nearest")


  offline_generator=offline_generator.flow(trainX, trainY, shuffle=True, batch_size=1, seed=generator_seed)

  #for all initial images
  for i in range(0,to_augment):
            batchx, batchy = next(offline_generator)
            X[i] = batchx[0]
            L[i] = np.argmax(batchy[0])
          
  
  labels = le.fit_transform(L)
  labels = tf.keras.utils.to_categorical(labels, 2)

  trainX = np.vstack((trainX, X))
  trainY = np.vstack((trainY, labels))


print("Shape training: ", trainX.shape)
print("Shape validation: ", testX.shape)
# Out:
# Shape training:  (17760, 32, 32, 3)
# Shape validation:  (1924, 32, 32, 3)

# %% [markdown]
# ## **Train the Model**
#
# We train the **model** and we save in a **CustomCallback** instance the average loss and accuracy for each training and validation batch. In this way, we can create a more defined training plot.

# %%
import torch, psutil


class MemoryUsage(tf.keras.callbacks.Callback):

   def __init__(self):
      # setting device on GPU if available, else CPU
      self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
      print('Using device for training:', self.device)
      self.max_RAM=[]
      self.max_GPU=[]

   def get_memory_usage(self):
      gpu_dict = tf.config.experimental.get_memory_info('GPU:0')
      tf.print('\n GPU memory details [current: {} gb, peak: {} gb]'.format(
          float(gpu_dict['current']) / (1024 ** 3), 
          float(gpu_dict['peak']) / (1024 ** 3)))
   
   def get_size(self, byte, suffix="GB"):
    factor = 1024
    
    for unit in ["", "K", "M", "GB", "T", "P"]:
        if byte < factor:
            return f"{byte:.2f} GB"
        byte /= factor

   def on_train_end(self, epoch, logs=None):
      i=np.argmax(self.max_RAM)
      self.get_memory_usage()
      print("MAX RAM USAGE: %s / %s (%s)" % (self.get_size(self.max_RAM[i][0]), self.get_size(self.max_RAM[i][1]), str(self.max_RAM[i][2]) + "%" ))
      


   
   def on_epoch_end(self,epoch,logs=None):
      svmem = psutil.virtual_memory()
      self.max_RAM.append((svmem.active, svmem.total, svmem.percent))
      #self.get_memory_usage()
      
      
      
      


# initialize the optimizer and model
print("[INFO] compiling model...")




#opt = tf.keras.optimizers.SGD(learning_rate=init_learning_rate, momentum = 0.5)
opt = tf.keras.optimizers.Adam(learning_rate=init_learning_rate)
#opt = tf.keras.optimizers.Adam(learning_rate=init_learning_rate)

#opt = tf.keras.optimizers.SGD(learning_rate=init_learning_rate, momentum = 0.5)
#opt = tf.keras.optimizers.Adam(learning_rate=init_learning_rate, decay=init_learning_rate/epochs)


#opt = tf.keras.optimizers.SGD(learning_rate=init_learning_rate, momentum = 0.99)
tf_seed()
model = LiveNet((final_y,final_x,n_channels))

callback_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=False)
memory_usage = MemoryUsage()


model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])  # same of binary_crossentropy in this case



import time
start_time = time.time()

#validation batch_size is equal to batch_size in this case (32)
#check https://github.com/keras-team/keras/blob/v2.9.0/keras/engine/training.py#L1099-L1472
if augmentation_online:
    H=model.fit(
      train_generator, 
      validation_data = (testX, testY), 
      callbacks = [memory_usage, callback_early_stopping],
      epochs= epochs)
else:
   
   H=model.fit(
      trainX, trainY, 
      batch_size = batch_size,
      shuffle=True,
      validation_data = (testX, testY), 
      callbacks = [memory_usage, callback_early_stopping],
      epochs= epochs)

print("TRAINING TIME")
print("--- %s seconds ---" % (time.time() - start_time))

import matplotlib.pyplot as plt

#print((history.epoch_batch_train_acc[0])) #show first epoch batches averaged values

print("[INFO] serializing network to '{}'...".format(save_model_h5))
model.save(save_model_h5, save_format="h5")


if not read_from_np_array:
   #save model labels 
      f = open(save_labels, "wb")
      f.write(pickle.dumps(label_encoder))
      f.close()


plt.style.use("ggplot")
plt.figure()
fig=plt.figure(figsize=(12,7))



new_epochs=len(H.history['loss'])
plt.plot(np.arange(0, new_epochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, new_epochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, new_epochs), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, new_epochs), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")


plt.savefig(save_training_metrics_plot)


# notice accuracy at the end of each epoch is the mean all over the batches, the same if we have more than 1 validation batch

#https://keras.io/guides/training_with_built_in_methods/
#https://keras.io/getting_started/faq/#why-is-my-training-loss-much-higher-than-my-testing-loss
#https://stackoverflow.com/questions/55097362/different-accuracy-by-fit-and-evaluate-in-keras-with-the-same-dataset

# the below code can give never seen images at each validation_step; more in general we divide validation dataset in batches
# see https://stackoverflow.com/questions/56991909/how-is-the-keras-accuracy-showed-in-progress-bar-calculated-from-which-inputs-i


#model.fit(train_generator,
 # steps_per_epoch=len(train_generator),
  #validation_data = validation_generator,
	#epochs=3)

# %% [markdown]
# ## Evaluation

# %%
#confusion matrix


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import itertools
from itertools import cycle
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size

model = tf.keras.models.load_model(save_model_h5)

y_score = model.predict(testX)

y_pred = np.argmax(y_score, axis = 1)
y_test_ = np.argmax(testY), axis = 1)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    print(cm)
  
    def precision(index):
      return round(cm[index][index] / cm[:, index].sum(),2)
    
    def recall(index):
      return round(cm[index][index] /cm[index].sum(),2)
    
    def F1_score(index):
      p=precision(index)
      r=recall(index)
      return round((2 * p * r)/(p + r),2)
    
    plt.figure(figsize=(6, 6), dpi=80)

    im = plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, round(cm[i, j],2),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
   

    #### CREATE THE PRECISION / RECALL / F1_SCORE TABLE ####

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    fig, ax1 = plt.subplots(figsize=(10, 2 + 3 / 2.5))
    
    col_labels=["Bonafide", "Attacker"]
    row_labels=['Precision','Recall','F1 Score']
    row_func=[precision,recall,F1_score]
    table_vals=[]  

    row_colors = np.full(len(row_labels), 'linen')
    col_colors = np.full(len(col_labels), 'lavender')

    
    for i in range(0, len(row_labels)):

      row=[]

      for j in range(0, len(col_labels)):
         row.append(row_func[i](j))

      table_vals.append(row)
    

    # the rectangle is where I want to place the table
    table = plt.table(cellText=table_vals,
                  cellLoc='center',
                  rowColours=row_colors,
                  rowLabels=row_labels,
                  rowLoc='center',
                  colColours=col_colors,
                  colLabels=col_labels,
                  loc='center')
    table.scale(1, 2)
    ax1.axis('off')

class_names = ["Bonafide", "Attacker"]

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test_, y_pred)

# Plot non-normalized confusion matrix
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion Matrix')


# we're using SoftMax
sigmoid=False

# if you use sigmoid as output, you can print one ROC Curve
if sigmoid:
    #ROC CURVE

    fpr, tpr, _ =  roc_curve(test_Y, y_score)
    roc_auc = auc(fpr, tpr)


    plt.figure(figsize=(5, 5), dpi=80)
    lw = 2

    plt.plot(fpr, tpr, color='darkorange',lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## Evaluation of our first trained model on Replay-Attack images

# %%
#confusion matrix


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import itertools
from itertools import cycle
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size

model = tf.keras.models.load_model(os.path.join(root_folder,"first_task_model.h5"))

y_score = model.predict(np.vstack((trainX,testX)))

y_pred = np.argmax(y_score, axis = 1)
y_test_ = np.argmax(np.vstack((trainY,testY)), axis = 1)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    print(cm)
  
    def precision(index):
      return round(cm[index][index] / cm[:, index].sum(),2)
    
    def recall(index):
      return round(cm[index][index] /cm[index].sum(),2)
    
    def F1_score(index):
      p=precision(index)
      r=recall(index)
      return round((2 * p * r)/(p + r),2)
    
    plt.figure(figsize=(6, 6), dpi=80)

    im = plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, round(cm[i, j],2),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
   

    #### CREATE THE PRECISION / RECALL / F1_SCORE TABLE ####

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    fig, ax1 = plt.subplots(figsize=(10, 2 + 3 / 2.5))
    
    col_labels=["Bonafide", "Attacker"]
    row_labels=['Precision','Recall','F1 Score']
    row_func=[precision,recall,F1_score]
    table_vals=[]  

    row_colors = np.full(len(row_labels), 'linen')
    col_colors = np.full(len(col_labels), 'lavender')

    
    for i in range(0, len(row_labels)):

      row=[]

      for j in range(0, len(col_labels)):
         row.append(row_func[i](j))

      table_vals.append(row)
    

    # the rectangle is where I want to place the table
    table = plt.table(cellText=table_vals,
                  cellLoc='center',
                  rowColours=row_colors,
                  rowLabels=row_labels,
                  rowLoc='center',
                  colColours=col_colors,
                  colLabels=col_labels,
                  loc='center')
    table.scale(1, 2)
    ax1.axis('off')

class_names = ["Bonafide", "Attacker"]

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test_, y_pred)

# Plot non-normalized confusion matrix
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion Matrix')


# we're using SoftMax
sigmoid=False

# if you use sigmoid as output, you can print one ROC Curve
if sigmoid:
    #ROC CURVE

    fpr, tpr, _ =  roc_curve(test_Y, y_score)
    roc_auc = auc(fpr, tpr)


    plt.figure(figsize=(5, 5), dpi=80)
    lw = 2

    plt.plot(fpr, tpr, color='darkorange',lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()
# Out:
# [[5176  226]
#  [3044 2358]]
# Confusion matrix, without normalization

# %% [markdown]
# ## RANDOM TESTING

# %%
model = tf.keras.models.load_model(save_model_h5)
le = pickle.loads(open(save_labels, "rb").read())

def extract_and_predict_faces(image):

    def translate(k):
      if k == 0:
        return "Real"
      return "Fake"

    extracted_test_faces, coordinates_faces = detect_save_face(
    image, multiple_output=True)

    for i in range(0, len(extracted_test_faces)):

        face = extracted_test_faces[i]
        (startX, startY, endX, endY) = coordinates_faces[i]

        if face is not None:

            #print(face)
            face = resize_normalize_image(face)
            face = face.astype("float")
            face = tf.keras.utils.img_to_array(face)
            face = np.expand_dims(face, axis=0)
            start_time = time.time()

            preds = model.predict(face)[0]

            print("--- inference in seconds : %f ---" % (time.time() - start_time))


            
            j = np.argmax(preds)
            label = le.classes_[j]
            
            
          #print(le.classes_)

            # draw the label and bounding box on the frame
            label = "{}: {:.4f}".format(translate(label), preds[j])
           
            print(label)

            cv2.putText(image, label, (startX - 150, startY + 55),
                        cv2.FONT_HERSHEY_SIMPLEX, 10, (0, 0, 255), 20)
            cv2.rectangle(image, (startX, startY), (endX, endY),
                      (0, 0, 255), 20)

def im_show(image, output=None):
   fig = plt.figure(figsize=(10, 10)) # set the height and width in inches
   plt.imshow(image, cmap="Greys")
   plt.axis("off")
   plt.show()

   if output is not None:
     cv2.imwrite(output, image)

# %%
image_for_test = os.path.join(root_folder,'Pp1.jpg') 

face_confidence=0.16


#we use an image we choose
tested_image = cv2.imread(image_for_test)

extract_and_predict_faces(tested_image)

im_show(tested_image, "face2.jpg")
# Out:
# --- inference in seconds : 0.048156 ---
# Fake: 1.0000
# --- inference in seconds : 0.047482 ---
# Fake: 1.0000

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  
  
  # Show the image which was just taken.
  image=cv2.imread(filename)

  print("Ok")
 
  extract_and_predict_faces(image)

  im_show(image)

  cv2.imwrite("photo.png", image)

  print('Saved to {}'.format("photo.png"))

except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Ok
# --- inference in seconds : 0.055904 ---
# Fake: 0.9999
# Saved to photo.png
