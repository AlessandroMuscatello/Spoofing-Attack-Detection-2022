# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We import all the main important **dependencies**

# %%
import random, os
import numpy as np
import tensorflow as tf
import cv2
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
from imutils import paths
from sklearn.model_selection import train_test_split
import pickle
import shutil


def tf_seed(seed=0):
  np.random.seed(seed)  # numpy seed
  tf.random.set_seed(seed)  # tensorflow seed
  random.seed(seed)  # random seed
  os.environ['TF_DETERMINISTIC_OPS'] = "1"
  os.environ['TF_CUDNN_DETERMINISM'] = "1"
  os.environ['PYTHONHASHSEED'] = str(seed)
  


tf_seed()

# %% [markdown]
# The main idea is to classify a **bonafide or attack** human face with a fast **CNN**, setting on the top of the network an **SSD** model, pretrained on a **ResNet**, that can extract faces from images.
#
# The network will have two main convolutional steps, in which we are going to extract deep features from the second phase. It uses in sequence **Conv2d + BatchNormalization** to learn faster, normalizing batch feature maps to avoid **overfitting**. However, this is why is important to set a right batch size and training data to avoid the opposite problem, then underfitting. The BatchNormalization, since this is a shallow network, won't have the so called vanishing gradient problem during the first training epochs.
#
# There are also, at the end of each phase, a Dropout layer. This is because it's important to learn as much details as possible to distinguish a "real or fake" person in front of a camera. So switching off weights during training randomly, will have the consequence to distribute better the learning of important features among all the weights.

# %% [markdown]
# # DEFINE NETWORK

# %% [markdown]
# ## Originary Network

# %%
def LiveNet(input_size):

  chan_dim=-1 #feature map channel

  #first convolutional phase
  input = tf.keras.layers.Input(input_size)
  x = tf.keras.layers.Conv2D(16, 3, activation = 'relu', padding = 'same')(input)
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.Conv2D(16, 3, activation = 'relu', padding = 'same')(x)
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
  x = tf.keras.layers.Dropout(0.25)(x)

  #second convolutional phase
  x = tf.keras.layers.Conv2D(32, 3, activation = 'relu', padding = 'same')(x)
  x = tf.keras.layers.BatchNormalization( axis=chan_dim)(x)
  x = tf.keras.layers.Conv2D(32, 3, activation = 'relu', padding = 'same')(x)

  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
  x = tf.keras.layers.Dropout(0.25)(x)

  #dense phase
  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(64, activation = 'relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)


  x = tf.keras.layers.Dropout(0.5)(x)  #to avoid overfitting 
  #softmax 
  output = tf.keras.layers.Dense(2, activation = 'softmax')(x)
 
  return tf.keras.models.Model(input, output)

# %% [markdown]
# ## AttackNet v2.1

# %%
def LiveNet(input_size):

  chan_dim=-1 #feature map channel

  #first convolutional phase
  input = tf.keras.layers.Input(input_size)
  y = tf.keras.layers.Conv2D(16, 3, padding = 'same')(input)
  x = tf.keras.layers.LeakyReLU(alpha=0.2)(y)
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.Conv2D(16, 3, padding = 'same')(x)
  x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
  x = tf.keras.layers.Conv2D(16, 3, padding = 'same')(x)
  z = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
  x = tf.keras.layers.concatenate([y,z])
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
  x = tf.keras.layers.Dropout(0.25)(x)

  #second convolutional phase
  y = tf.keras.layers.Conv2D(32, 3, padding = 'same')(x)
  x = tf.keras.layers.LeakyReLU(alpha=0.2)(y)
  x = tf.keras.layers.BatchNormalization( axis=chan_dim)(x)
  x = tf.keras.layers.Conv2D(32, 3, padding = 'same')(x)
  x = tf.keras.layers.Conv2D(32, 3, padding = 'same')(x)
  z = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
  x = tf.keras.layers.concatenate([y,z])
  x = tf.keras.layers.BatchNormalization(axis=chan_dim)(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
  x = tf.keras.layers.Dropout(0.25)(x)

  #dense phase
  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(128, activation = 'tanh')(x)
  #x = BatchNormalization()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  #softmax 
  output = tf.keras.layers.Dense(2, activation = 'softmax')(x)
 
  return tf.keras.models.Model(input, output)

# %% [markdown]
# # MSSPOOF DATASET

# %% [markdown]
# We define absolute paths that will be used.
#
# The dataset is the following: https://www.idiap.ch/en/dataset/msspoof
#
# I. Chingovska, N. Erdogmus, A. Anjos. S. Marcel, “Face Recognition Systems Under Spoofing Attacks”, in Springer “Face Recognition Across the Imaging Spectrum” (Editor Thirimachos Bourlai), 2016.
# 10.1007/978-3-319-28501-6_8
# https://publications.idiap.ch/index.php/publications/show/3539
#
# <br><br>
# Multispectral-Spoof contains face images and printed spoofing attacks recorded in Visible (VIS) and Near-Infrared (NIR) spectra for 21 identities.
#
#
# ## Dataset Structure
#
# We get a subset of the original dataset, so in our case is organized in two subdirectories: **attack**, **real**. The two directories **attack** and **real** contain images for attacks and bona fide presentations, respectively, both with VIS and NIR acquisitions.
#
# ## Training and Validation Data
#
# In **real** and **attack** folders, we find the **NIR** and **VIS** folders, and for each of them we have **training** and **testing** folders. We include in the training also images in **dev** folder.
# Nothing included in the **testing** folder will be seen during training.

# %% [markdown]
# ## Define Root Folders

# %%
root_folder="/content/drive/MyDrive/liveness_project/"


protoPath=os.path.join(root_folder,'face_detector/deploy.prototxt.txt')
modelPath = os.path.join(root_folder,
	"face_detector/res10_300x300_ssd_iter_140000.caffemodel")


face_confidence=0.68

MSSpoof_extracted=os.path.join(root_folder,'dataset/training/MSSpoof/images/')




#we define where to save output detected faces and the corresponding depth
output_attack_training_folder=os.path.join(root_folder,'dataset/training/MSSpoof_dataset/images/attack_training/')
output_attack_validation_folder=os.path.join(root_folder,'dataset/training/MSSpoof_dataset/images/attack_validation/')

output_bonifade_training_folder=os.path.join(root_folder,'dataset/training/MSSpoof_dataset/images/bonifade_training/')
output_bonifade_validation_folder=os.path.join(root_folder,'dataset/training/MSSpoof_dataset/images/bonifade_validation/')


save_augmented_images =  os.path.join(root_folder,'dataset/training/MSSpoof/augmented_images/') #output of online augmented images 
save_model_h5 = os.path.join(root_folder,'model_MSSpoof.h5') 
save_labels = os.path.join(root_folder,'model_MSSpoof_labels')
save_training_metrics_plot = os.path.join(root_folder,'MSSpoof_plot.png')

output_np_training_array = os.path.join(root_folder,'MSSpoof_training_array')



def get_folders(image_type, training):
	init_folders=[]

	new_root=os.path.join(MSSpoof_extracted,image_type) #ex. images/attack/


	init_folders.append(os.path.join(new_root, "VS")) #ex. images/attack/VS
	init_folders.append(os.path.join(new_root, "IR")) #ex. images/attack/IR

	final_folders=[]
	 
	if image_type=="attack": 

		for folder in init_folders:
			#ex. images/attack/VS
			if training:
				final_folders.append(os.path.join(folder, "VS","train")) #ex. images/attack/VS/VS/train
				final_folders.append(os.path.join(folder, "VS","dev"))
				final_folders.append(os.path.join(folder, "IR","train"))
				final_folders.append(os.path.join(folder, "IR","dev"))
			else:
				final_folders.append(os.path.join(folder, "VS","test")) #ex. images/attack/VS/VS/test
				final_folders.append(os.path.join(folder, "IR","test"))

	  	#result for ex. 	images/attack/VS/VS/train,images/attack/VS/VS/dev,images/attack/VS/IR/train,images/attack/VS/IR/dev

	
	else:
		 for folder in init_folders:
			#ex. images/real/VS
			 if training:
				  final_folders.append(os.path.join(folder, "train")) #ex. images/real/VS/train
				  final_folders.append(os.path.join(folder, "dev"))
			 else:
				  final_folders.append(os.path.join(folder, "test")) #ex. images/real/VS/test

	  	#result for ex. 	images/attack/VS/train,images/attack/VS/dev,images/attack/VS/train

	return final_folders


attack_folders_training = get_folders("attack",training=True)
attack_folders_validation = get_folders("attack",training=False)

bonifade_folders_training = get_folders("real",training=True)
bonifade_folders_validation = get_folders("real",training=True)

training_directories=[attack_folders_training, attack_folders_validation, bonifade_folders_training, bonifade_folders_validation]
output_directories=[output_attack_training_folder, output_attack_validation_folder, output_bonifade_training_folder, output_bonifade_validation_folder]


#create directories where to save images if they don't exist
for output_dir in output_directories:
	if not os.path.exists(output_dir): 
	  os.makedirs(output_dir)
	  print("created ",  output_dir)
	 
	 
print("Attack folders for training: " , attack_folders_training)
print("Attack folders for validation: " , attack_folders_validation)
print("Bonifade folders for training: " , bonifade_folders_training)
print("Bonifade folders for validation: " , bonifade_folders_validation)
# Out:
# Attack folders for training:  ['/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/VS/VS/train', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/VS/VS/dev', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/VS/IR/train', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/VS/IR/dev', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/IR/VS/train', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/IR/VS/dev', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/IR/IR/train', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/IR/IR/dev']
# Attack folders for validation:  ['/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/VS/VS/test', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/VS/IR/test', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/IR/VS/test', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/IR/IR/test']
# Bonifade folders for training:  ['/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/VS/train', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/VS/dev', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/IR/train', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/IR/dev']
# Bonifade folders for validation:  ['/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/VS/train', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/VS/dev', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/IR/train', '/content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/IR/dev']

# %% [markdown]
# # NETWORK PARAMETERS FOR TRAINING

# %%
final_x = 32
final_y = 32

n_channels = 3

dim = (final_x, final_y)

epochs=30
batch_size=16
init_learning_rate= 1e-4

#return normalized image
def resize_normalize_image(image):
  image=cv2.resize(image, dim)
  return (image)/np.max(image)

# %% [markdown]
# # FACE PROCESSING

# %% [markdown]
# ## Network to Detect Faces
#
# We define the SSD network that detects face inside an image.
#
# In this case, since we want to save in .pgm format, we convert image to grayscale before, otherwise `cv2.imwrite` won't work correctly.

# %%
#read ssd model to detect faces
net = cv2.dnn.readNetFromCaffe(protoPath, modelPath) 


# detect the most probable face, or all of detected face
# return coordinates of bounding box for each face and the face itself as a cv2 object
def detect_save_face(frame, output_path=None, multiple_output=False):

    (h, w) = frame.shape[:2]

    # we preprocess image normalizing each r-g-b channel subtracting the values in the last tuple
    blob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)), 1.0,
                                 (300, 300), (104.0, 177.0, 123.0))
    # pass the blob through the network and obtain the detections and
    # predictions
    net.setInput(blob)
    detections = net.forward()   #output => (1, 1, 20, [1, 0.9, .... ]   )
    faces = []
    coordinates=[]
    
    # ensure at least one face was found
    if len(detections) > 0:

       
        
        max_i=np.argmax(detections[0, 0, :, 2]) #this is the most probable detected face

        #if we want to output the most probable detected face or all the faces
        min_range = 0 if multiple_output==True else max_i 
        max_range = detections.shape[2] if multiple_output==True else max_i + 1

        for i in range(min_range, max_range):

          # we get the model confidence
          confidence = detections[0, 0, i, 2]

          if confidence >= face_confidence:
            # compute the (x, y)-coordinates of the bounding box for
            # the face and extract the face ROI
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # we save coordinates 
            coordinates.append(box.astype("int"))
            face = frame[startY:endY, startX:endX]

            #we save the face
            faces.append(face)
            

            try:
            
              #we save the image if output_path is defined
              if output_path is not None:
                gray = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
                cv2.imwrite(output_path, gray)
             
            except:
              print("error")
              pass

    return faces, coordinates

#frame_mask_output = [mask_genuine_folder, mask_fake_folder]

#return file name given a path
def get_file_name(path):
    base = os.path.basename(path)
    return os.path.splitext(base)[0]

#return file extension given a path
def get_file_type(path): 
    base = os.path.basename(path)
    return os.path.splitext(base)[1] # ex. .png, .jpg

print(get_file_type("file.png"))
# Out:
# .png

# %% [markdown]
# ## Extract Faces from Images
#
# We are going to take videos or images from our dataset. For each frame will be detected **one** face, and this one will be saved to the output folders defined before. The code reserves the possibility for the user to define also a mask for each image. In this case, the detected face will be also "cropped" from the mask.

# %%
max_images_per_folder=2000000 #we want to take a maximum number of images for training since limited hardware resources


#for each training input directory, search for color image
#for each color image (RGB), we take the corresponding align_to_depth and depth images 
#for each image and depth, we detect one face
def take_images():
    directory_counter = 0
    file_counter = 0

    for main_list in training_directories:

          folder_file_counter=0

          d_index=0

          print("we're on array %d/%d" % (directory_counter + 1, len(training_directories)))


          for directory in main_list:

            d_index+=1

            print("we're on %s" % directory)

          # files = [file for file in os.listdir(directory[0])]

            list_images = [file for file in os.listdir(directory)]

            #we shuffle training data since we just take a limited number of images
            random.Random(20).shuffle(list_images)

            print("found %d images for folder n. %d/%d" % (len(list_images), d_index, len(main_list)))

            for file in list_images:

                file_path=os.path.join(directory, file)

                if folder_file_counter > max_images_per_folder:
                  break

              #  file_path = os.path.join(directory, file)
                
                color=cv2.imread(file_path)
                              
                detect_save_face(color,  (os.path.join(output_directories[directory_counter], "%s%s" % (
                        "frame_%d" % file_counter, get_file_type(file_path)))))
                    
                folder_file_counter+=1

                print("save face detected on image n. %d, for folder n. %d" % (file_counter, directory_counter + 1))


                file_counter += 1

          directory_counter += 1


take_images()
# Out:
# we're on array 1/4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/attack/VS/VS/train
# found 324 images for folder n. 1/8
# save face detected on image n. 0, for folder n. 1
# save face detected on image n. 1, for folder n. 1
# save face detected on image n. 2, for folder n. 1
# save face detected on image n. 3, for folder n. 1
# save face detected on image n. 4, for folder n. 1
# save face detected on image n. 5, for folder n. 1
# save face detected on image n. 6, for folder n. 1
# save face detected on image n. 7, for folder n. 1
# save face detected on image n. 8, for folder n. 1
# save face detected on image n. 9, for folder n. 1
# save face detected on image n. 10, for folder n. 1
# save face detected on image n. 11, for folder n. 1
# save face detected on image n. 12, for folder n. 1
# save face detected on image n. 13, for folder n. 1
# save face detected on image n. 14, for folder n. 1
# save face detected on image n. 15, for folder n. 1
# save face detected on image n. 16, for folder n. 1
# save face detected on image n. 17, for folder n. 1
# save face detected on image n. 18, for folder n. 1
# save face detected on image n. 19, for folder n. 1
# save face detected on image n. 20, for folder n. 1
# save face detected on image n. 21, for folder n. 1
# save face detected on image n. 22, for folder n. 1
# save face detected on image n. 23, for folder n. 1
# save face detected on image n. 24, for folder n. 1
# save face detected on image n. 25, for folder n. 1
# save face detected on image n. 26, for folder n. 1
# save face detected on image n. 27, for folder n. 1
# save face detected on image n. 28, for folder n. 1
# save face detected on image n. 29, for folder n. 1
# save face detected on image n. 30, for folder n. 1
# save face detected on image n. 31, for folder n. 1
# save face detected on image n. 32, for folder n. 1
# save face detected on image n. 33, for folder n. 1
# save face detected on image n. 34, for folder n. 1
# save face detected on image n. 35, for folder n. 1
# save face detected on image n. 36, for folder n. 1
# save face detected on image n. 37, for folder n. 1
# save face detected on image n. 38, for folder n. 1
# save face detected on image n. 39, for folder n. 1
# save face detected on image n. 40, for folder n. 1
# save face detected on image n. 41, for folder n. 1
# save face detected on image n. 42, for folder n. 1
# save face detected on image n. 43, for folder n. 1
# save face detected on image n. 44, for folder n. 1
# save face detected on image n. 45, for folder n. 1
# save face detected on image n. 46, for folder n. 1
# save face detected on image n. 47, for folder n. 1
# save face detected on image n. 48, for folder n. 1
# save face detected on image n. 49, for folder n. 1
# save face detected on image n. 50, for folder n. 1
# save face detected on image n. 51, for folder n. 1
# save face detected on image n. 52, for folder n. 1
# save face detected on image n. 53, for folder n. 1
# save face detected on image n. 54, for folder n. 1
# save face detected on image n. 55, for folder n. 1
# save face detected on image n. 56, for folder n. 1
# save face detected on image n. 57, for folder n. 1
# save face detected on image n. 58, for folder n. 1
# save face detected on image n. 59, for folder n. 1
# save face detected on image n. 60, for folder n. 1
# save face detected on image n. 61, for folder n. 1
# save face detected on image n. 62, for folder n. 1
# save face detected on image n. 63, for folder n. 1
# save face detected on image n. 64, for folder n. 1
# save face detected on image n. 65, for folder n. 1
# save face detected on image n. 66, for folder n. 1
# save face detected on image n. 67, for folder n. 1
# save face detected on image n. 68, for folder n. 1
# save face detected on image n. 69, for folder n. 1
# save face detected on image n. 70, for folder n. 1
# save face detected on image n. 71, for folder n. 1
# save face detected on image n. 72, for folder n. 1
# save face detected on image n. 73, for folder n. 1
# save face detected on image n. 74, for folder n. 1
# save face detected on image n. 75, for folder n. 1
# save face detected on image n. 76, for folder n. 1
# save face detected on image n. 77, for folder n. 1
# save face detected on image n. 78, for folder n. 1
# save face detected on image n. 79, for folder n. 1
# save face detected on image n. 80, for folder n. 1
# save face detected on image n. 81, for folder n. 1
# save face detected on image n. 82, for folder n. 1
# save face detected on image n. 83, for folder n. 1
# save face detected on image n. 84, for folder n. 1
# save face detected on image n. 85, for folder n. 1
# save face detected on image n. 86, for folder n. 1
# save face detected on image n. 87, for folder n. 1
# save face detected on image n. 88, for folder n. 1
# save face detected on image n. 89, for folder n. 1
# save face detected on image n. 90, for folder n. 1
# save face detected on image n. 91, for folder n. 1
# save face detected on image n. 92, for folder n. 1
# save face detected on image n. 93, for folder n. 1
# save face detected on image n. 94, for folder n. 1
# save face detected on image n. 95, for folder n. 1
# save face detected on image n. 96, for folder n. 1
# save face detected on image n. 97, for folder n. 1
# save face detected on image n. 98, for folder n. 1
# save face detected on image n. 99, for folder n. 1
# save face detected on image n. 100, for folder n. 1
# save face detected on image n. 101, for folder n. 1
# save face detected on image n. 102, for folder n. 1
# save face detected on image n. 103, for folder n. 1
# save face detected on image n. 104, for folder n. 1
# save face detected on image n. 105, for folder n. 1
# save face detected on image n. 106, for folder n. 1
# save face detected on image n. 107, for folder n. 1
# save face detected on image n. 108, for folder n. 1
# save face detected on image n. 109, for folder n. 1
# save face detected on image n. 110, for folder n. 1
# save face detected on image n. 111, for folder n. 1
# save face detected on image n. 112, for folder n. 1
# save face detected on image n. 113, for folder n. 1
# save face detected on image n. 114, for folder n. 1
# save face detected on image n. 115, for folder n. 1
# save face detected on image n. 116, for folder n. 1
# save face detected on image n. 117, for folder n. 1
# save face detected on image n. 118, for folder n. 1
# save face detected on image n. 119, for folder n. 1
# save face detected on image n. 120, for folder n. 1
# save face detected on image n. 121, for folder n. 1
# save face detected on image n. 122, for folder n. 1
# save face detected on image n. 123, for folder n. 1
# save face detected on image n. 124, for folder n. 1
# save face detected on image n. 125, for folder n. 1
# save face detected on image n. 126, for folder n. 1
# save face detected on image n. 127, for folder n. 1
# save face detected on image n. 128, for folder n. 1
# save face detected on image n. 129, for folder n. 1
# save face detected on image n. 130, for folder n. 1
# save face detected on image n. 131, for folder n. 1
# save face detected on image n. 132, for folder n. 1
# save face detected on image n. 133, for folder n. 1
# save face detected on image n. 134, for folder n. 1
# save face detected on image n. 135, for folder n. 1
# save face detected on image n. 136, for folder n. 1
# save face detected on image n. 137, for folder n. 1
# save face detected on image n. 138, for folder n. 1
# save face detected on image n. 139, for folder n. 1
# save face detected on image n. 140, for folder n. 1
# save face detected on image n. 141, for folder n. 1
# save face detected on image n. 142, for folder n. 1
# save face detected on image n. 143, for folder n. 1
# save face detected on image n. 144, for folder n. 1
# save face detected on image n. 145, for folder n. 1
# save face detected on image n. 146, for folder n. 1
# save face detected on image n. 147, for folder n. 1
# save face detected on image n. 148, for folder n. 1
# save face detected on image n. 149, for folder n. 1
# save face detected on image n. 150, for folder n. 1
# save face detected on image n. 151, for folder n. 1
# save face detected on image n. 152, for folder n. 1
# save face detected on image n. 153, for folder n. 1
# save face detected on image n. 154, for folder n. 1
# save face detected on image n. 155, for folder n. 1
# save face detected on image n. 156, for folder n. 1
# save face detected on image n. 157, for folder n. 1
# save face detected on image n. 158, for folder n. 1
# save face detected on image n. 159, for folder n. 1
# save face detected on image n. 4509, for folder n. 4
# save face detected on image n. 4510, for folder n. 4
# save face detected on image n. 4511, for folder n. 4
# save face detected on image n. 4512, for folder n. 4
# save face detected on image n. 4513, for folder n. 4
# save face detected on image n. 4514, for folder n. 4
# save face detected on image n. 4515, for folder n. 4
# save face detected on image n. 4516, for folder n. 4
# save face detected on image n. 4517, for folder n. 4
# save face detected on image n. 4518, for folder n. 4
# save face detected on image n. 4519, for folder n. 4
# save face detected on image n. 4520, for folder n. 4
# save face detected on image n. 4521, for folder n. 4
# save face detected on image n. 4522, for folder n. 4
# save face detected on image n. 4523, for folder n. 4
# save face detected on image n. 4524, for folder n. 4
# save face detected on image n. 4525, for folder n. 4
# save face detected on image n. 4526, for folder n. 4
# save face detected on image n. 4527, for folder n. 4
# save face detected on image n. 4528, for folder n. 4
# save face detected on image n. 4529, for folder n. 4
# save face detected on image n. 4530, for folder n. 4
# save face detected on image n. 4531, for folder n. 4
# save face detected on image n. 4532, for folder n. 4
# save face detected on image n. 4533, for folder n. 4
# save face detected on image n. 4534, for folder n. 4
# save face detected on image n. 4535, for folder n. 4
# save face detected on image n. 4536, for folder n. 4
# save face detected on image n. 4537, for folder n. 4
# save face detected on image n. 4538, for folder n. 4
# save face detected on image n. 4539, for folder n. 4
# save face detected on image n. 4540, for folder n. 4
# save face detected on image n. 4541, for folder n. 4
# save face detected on image n. 4542, for folder n. 4
# save face detected on image n. 4543, for folder n. 4
# save face detected on image n. 4544, for folder n. 4
# save face detected on image n. 4545, for folder n. 4
# save face detected on image n. 4546, for folder n. 4
# save face detected on image n. 4547, for folder n. 4
# save face detected on image n. 4548, for folder n. 4
# save face detected on image n. 4549, for folder n. 4
# save face detected on image n. 4550, for folder n. 4
# save face detected on image n. 4551, for folder n. 4
# save face detected on image n. 4552, for folder n. 4
# save face detected on image n. 4553, for folder n. 4
# save face detected on image n. 4554, for folder n. 4
# save face detected on image n. 4555, for folder n. 4
# save face detected on image n. 4556, for folder n. 4
# save face detected on image n. 4557, for folder n. 4
# save face detected on image n. 4558, for folder n. 4
# save face detected on image n. 4559, for folder n. 4
# save face detected on image n. 4560, for folder n. 4
# save face detected on image n. 4561, for folder n. 4
# save face detected on image n. 4562, for folder n. 4
# save face detected on image n. 4563, for folder n. 4
# save face detected on image n. 4564, for folder n. 4
# save face detected on image n. 4565, for folder n. 4
# save face detected on image n. 4566, for folder n. 4
# save face detected on image n. 4567, for folder n. 4
# save face detected on image n. 4568, for folder n. 4
# save face detected on image n. 4569, for folder n. 4
# save face detected on image n. 4570, for folder n. 4
# save face detected on image n. 4571, for folder n. 4
# save face detected on image n. 4572, for folder n. 4
# save face detected on image n. 4573, for folder n. 4
# save face detected on image n. 4574, for folder n. 4
# save face detected on image n. 4575, for folder n. 4
# save face detected on image n. 4576, for folder n. 4
# save face detected on image n. 4577, for folder n. 4
# save face detected on image n. 4578, for folder n. 4
# save face detected on image n. 4579, for folder n. 4
# save face detected on image n. 4580, for folder n. 4
# save face detected on image n. 4581, for folder n. 4
# save face detected on image n. 4582, for folder n. 4
# save face detected on image n. 4583, for folder n. 4
# save face detected on image n. 4584, for folder n. 4
# save face detected on image n. 4585, for folder n. 4
# save face detected on image n. 4586, for folder n. 4
# save face detected on image n. 4587, for folder n. 4
# save face detected on image n. 4588, for folder n. 4
# save face detected on image n. 4589, for folder n. 4
# save face detected on image n. 4590, for folder n. 4
# save face detected on image n. 4591, for folder n. 4
# save face detected on image n. 4592, for folder n. 4
# save face detected on image n. 4593, for folder n. 4
# save face detected on image n. 4594, for folder n. 4
# save face detected on image n. 4595, for folder n. 4
# save face detected on image n. 4596, for folder n. 4
# save face detected on image n. 4597, for folder n. 4
# save face detected on image n. 4598, for folder n. 4
# save face detected on image n. 4599, for folder n. 4
# save face detected on image n. 4600, for folder n. 4
# save face detected on image n. 4601, for folder n. 4
# save face detected on image n. 4602, for folder n. 4
# save face detected on image n. 4603, for folder n. 4
# save face detected on image n. 4604, for folder n. 4
# save face detected on image n. 4605, for folder n. 4
# save face detected on image n. 4606, for folder n. 4
# save face detected on image n. 4607, for folder n. 4
# save face detected on image n. 4608, for folder n. 4
# save face detected on image n. 4609, for folder n. 4
# save face detected on image n. 4610, for folder n. 4
# save face detected on image n. 4611, for folder n. 4
# save face detected on image n. 4612, for folder n. 4
# save face detected on image n. 4613, for folder n. 4
# save face detected on image n. 4614, for folder n. 4
# save face detected on image n. 4615, for folder n. 4
# save face detected on image n. 4616, for folder n. 4
# save face detected on image n. 4617, for folder n. 4
# save face detected on image n. 4618, for folder n. 4
# we're on /content/drive/MyDrive/liveness_project/dataset/training/MSSpoof/images/real/IR/dev
# found 179 images for folder n. 4/4
# save face detected on image n. 4619, for folder n. 4
# save face detected on image n. 4620, for folder n. 4
# save face detected on image n. 4621, for folder n. 4
# save face detected on image n. 4622, for folder n. 4
# save face detected on image n. 4623, for folder n. 4
# save face detected on image n. 4624, for folder n. 4
# save face detected on image n. 4625, for folder n. 4
# save face detected on image n. 4626, for folder n. 4
# save face detected on image n. 4627, for folder n. 4
# save face detected on image n. 4628, for folder n. 4
# save face detected on image n. 4629, for folder n. 4
# save face detected on image n. 4630, for folder n. 4
# save face detected on image n. 4631, for folder n. 4
# save face detected on image n. 4632, for folder n. 4
# save face detected on image n. 4633, for folder n. 4
# save face detected on image n. 4634, for folder n. 4
# save face detected on image n. 4635, for folder n. 4
# save face detected on image n. 4636, for folder n. 4
# save face detected on image n. 4637, for folder n. 4
# save face detected on image n. 4638, for folder n. 4
# save face detected on image n. 4639, for folder n. 4
# save face detected on image n. 4640, for folder n. 4
# save face detected on image n. 4641, for folder n. 4
# save face detected on image n. 4642, for folder n. 4
# save face detected on image n. 4643, for folder n. 4
# save face detected on image n. 4644, for folder n. 4
# save face detected on image n. 4645, for folder n. 4
# save face detected on image n. 4646, for folder n. 4
# save face detected on image n. 4647, for folder n. 4
# save face detected on image n. 4648, for folder n. 4
# save face detected on image n. 4649, for folder n. 4
# save face detected on image n. 4650, for folder n. 4
# save face detected on image n. 4651, for folder n. 4
# save face detected on image n. 4652, for folder n. 4
# save face detected on image n. 4653, for folder n. 4
# save face detected on image n. 4654, for folder n. 4
# save face detected on image n. 4655, for folder n. 4
# save face detected on image n. 4656, for folder n. 4
# save face detected on image n. 4657, for folder n. 4
# save face detected on image n. 4658, for folder n. 4
# save face detected on image n. 4659, for folder n. 4
# save face detected on image n. 4660, for folder n. 4
# save face detected on image n. 4661, for folder n. 4
# save face detected on image n. 4662, for folder n. 4
# save face detected on image n. 4663, for folder n. 4
# save face detected on image n. 4664, for folder n. 4
# save face detected on image n. 4665, for folder n. 4
# save face detected on image n. 4666, for folder n. 4
# save face detected on image n. 4667, for folder n. 4
# save face detected on image n. 4668, for folder n. 4
# save face detected on image n. 4669, for folder n. 4
# save face detected on image n. 4670, for folder n. 4
# save face detected on image n. 4671, for folder n. 4
# save face detected on image n. 4672, for folder n. 4
# save face detected on image n. 4673, for folder n. 4
# save face detected on image n. 4674, for folder n. 4
# save face detected on image n. 4675, for folder n. 4
# save face detected on image n. 4676, for folder n. 4
# save face detected on image n. 4677, for folder n. 4
# save face detected on image n. 4678, for folder n. 4
# save face detected on image n. 4679, for folder n. 4
# save face detected on image n. 4680, for folder n. 4
# save face detected on image n. 4681, for folder n. 4
# save face detected on image n. 4682, for folder n. 4
# save face detected on image n. 4683, for folder n. 4
# save face detected on image n. 4684, for folder n. 4
# save face detected on image n. 4685, for folder n. 4
# save face detected on image n. 4686, for folder n. 4
# save face detected on image n. 4687, for folder n. 4
# save face detected on image n. 4688, for folder n. 4
# save face detected on image n. 4689, for folder n. 4
# save face detected on image n. 4690, for folder n. 4
# save face detected on image n. 4691, for folder n. 4
# save face detected on image n. 4692, for folder n. 4
# save face detected on image n. 4693, for folder n. 4
# save face detected on image n. 4694, for folder n. 4
# save face detected on image n. 4695, for folder n. 4
# save face detected on image n. 4696, for folder n. 4
# save face detected on image n. 4697, for folder n. 4
# save face detected on image n. 4698, for folder n. 4
# save face detected on image n. 4699, for folder n. 4
# save face detected on image n. 4700, for folder n. 4
# save face detected on image n. 4701, for folder n. 4
# save face detected on image n. 4702, for folder n. 4
# save face detected on image n. 4703, for folder n. 4
# save face detected on image n. 4704, for folder n. 4
# save face detected on image n. 4705, for folder n. 4
# save face detected on image n. 4706, for folder n. 4
# save face detected on image n. 4707, for folder n. 4
# save face detected on image n. 4708, for folder n. 4
# save face detected on image n. 4709, for folder n. 4
# save face detected on image n. 4710, for folder n. 4
# save face detected on image n. 4711, for folder n. 4
# save face detected on image n. 4712, for folder n. 4
# save face detected on image n. 4713, for folder n. 4
# save face detected on image n. 4714, for folder n. 4
# save face detected on image n. 4715, for folder n. 4
# save face detected on image n. 4716, for folder n. 4
# save face detected on image n. 4717, for folder n. 4
# save face detected on image n. 4718, for folder n. 4
# save face detected on image n. 4719, for folder n. 4
# save face detected on image n. 4720, for folder n. 4
# save face detected on image n. 4721, for folder n. 4
# save face detected on image n. 4722, for folder n. 4
# save face detected on image n. 4723, for folder n. 4
# save face detected on image n. 4724, for folder n. 4
# save face detected on image n. 4725, for folder n. 4
# save face detected on image n. 4726, for folder n. 4
# save face detected on image n. 4727, for folder n. 4
# save face detected on image n. 4728, for folder n. 4
# save face detected on image n. 4729, for folder n. 4
# save face detected on image n. 4730, for folder n. 4
# save face detected on image n. 4731, for folder n. 4
# save face detected on image n. 4732, for folder n. 4
# save face detected on image n. 4733, for folder n. 4
# save face detected on image n. 4734, for folder n. 4
# save face detected on image n. 4735, for folder n. 4
# save face detected on image n. 4736, for folder n. 4
# save face detected on image n. 4737, for folder n. 4
# save face detected on image n. 4738, for folder n. 4
# save face detected on image n. 4739, for folder n. 4
# save face detected on image n. 4740, for folder n. 4
# save face detected on image n. 4741, for folder n. 4
# save face detected on image n. 4742, for folder n. 4
# save face detected on image n. 4743, for folder n. 4
# save face detected on image n. 4744, for folder n. 4
# save face detected on image n. 4745, for folder n. 4
# save face detected on image n. 4746, for folder n. 4
# save face detected on image n. 4747, for folder n. 4
# save face detected on image n. 4748, for folder n. 4
# save face detected on image n. 4749, for folder n. 4
# save face detected on image n. 4750, for folder n. 4
# save face detected on image n. 4751, for folder n. 4
# save face detected on image n. 4752, for folder n. 4
# save face detected on image n. 4753, for folder n. 4
# save face detected on image n. 4754, for folder n. 4
# save face detected on image n. 4755, for folder n. 4
# save face detected on image n. 4756, for folder n. 4
# save face detected on image n. 4757, for folder n. 4
# save face detected on image n. 4758, for folder n. 4
# save face detected on image n. 4759, for folder n. 4
# save face detected on image n. 4760, for folder n. 4
# save face detected on image n. 4761, for folder n. 4
# save face detected on image n. 4762, for folder n. 4
# save face detected on image n. 4763, for folder n. 4
# save face detected on image n. 4764, for folder n. 4
# save face detected on image n. 4765, for folder n. 4
# save face detected on image n. 4766, for folder n. 4
# save face detected on image n. 4767, for folder n. 4
# save face detected on image n. 4768, for folder n. 4
# save face detected on image n. 4769, for folder n. 4
# save face detected on image n. 4770, for folder n. 4
# save face detected on image n. 4771, for folder n. 4
# save face detected on image n. 4772, for folder n. 4
# save face detected on image n. 4773, for folder n. 4
# save face detected on image n. 4774, for folder n. 4
# save face detected on image n. 4775, for folder n. 4
# save face detected on image n. 4776, for folder n. 4
# save face detected on image n. 4777, for folder n. 4
# save face detected on image n. 4778, for folder n. 4
# save face detected on image n. 4779, for folder n. 4
# save face detected on image n. 4780, for folder n. 4
# save face detected on image n. 4781, for folder n. 4
# save face detected on image n. 4782, for folder n. 4
# save face detected on image n. 4783, for folder n. 4
# save face detected on image n. 4784, for folder n. 4
# save face detected on image n. 4785, for folder n. 4
# save face detected on image n. 4786, for folder n. 4
# save face detected on image n. 4787, for folder n. 4
# save face detected on image n. 4788, for folder n. 4
# save face detected on image n. 4789, for folder n. 4
# save face detected on image n. 4790, for folder n. 4
# save face detected on image n. 4791, for folder n. 4
# save face detected on image n. 4792, for folder n. 4
# save face detected on image n. 4793, for folder n. 4
# save face detected on image n. 4794, for folder n. 4
# save face detected on image n. 4795, for folder n. 4
# save face detected on image n. 4796, for folder n. 4
# save face detected on image n. 4797, for folder n. 4

# %% [markdown]
# # TRAINING SECTION

# %% [markdown]
# ## Get Training and Validation Data
#
# For each directory where we saved detected faces, we are going to create two arrays: images, that will be concatenated with the depth mask, **by default**, and labels (0 for bonafide, 1 for attackers)

# %%
def get_images(directories, balance_dataset=True, undersampling=False):

    image_list = []
    label_list = []

    classes = 0

    images_per_class=[]

    tf_seed()

    #for each input directory
    for i in directories:

        list_images = [f for f in os.listdir(i) if os.path.isfile(os.path.join(i, f))]

        images_number = len(list_images)

        random.Random(20).shuffle(list_images)



        print("n %d" % images_number)

        #if we use undersampling
        if undersampling:
          images_number = images_number if ((len(images_per_class) == 0) or (images_number <= images_per_class[-1]))  else images_per_class[-1]
        
        
        # to fill tensors we inizialise them
        X = np.empty((images_number, final_x, final_y, n_channels))

        L = np.empty((images_number))

        ipp = 0

        for im_name in list_images:
            
            im=os.path.join(i, im_name)


            # to get "balanced dataset" using undersampling method
            if (balance_dataset and undersampling) and len(images_per_class)  and ipp == images_per_class[-1]:
                break

            image = cv2.imread(im)
            image=resize_normalize_image(image)

          
                

            X[ipp, ..., :3] = image # each original image is rgb
            L[ipp] = classes  # 0 for real, 1 for fake for binary classification

            ipp += 1
        
        # check if the current class has lower images than the before
        # in this case we undersample the majority class randomly removing elements
        # we will have a balanced dataset: same images for all the classes

        if balance_dataset and undersampling:
            if len(images_per_class) and ipp < images_per_class[-1]:
            
              left_shift = 0

              for i in range(0, len(images_per_class)):

                  diff = images_per_class[i] - ipp

                  for j in range(0, diff):
                      random_index = np.random.randint(left_shift, images_per_class[i] - j)
                      image_list.pop(random_index)
                      label_list.pop(random_index)
                    #  print(random_index)

                  left_shift += images_per_class[i] - diff

        if undersampling or balance_dataset==False:
              for image in X:
                image_list.append(image)

              for label in L:
                label_list.append(label)
        else:
              image_array=[]
              label_array=[]
            
              for image in X:
                image_array.append(image)

              image_list.append(np.array(image_array, dtype="float"))

             
              for label in L:
                label_array.append(label)

              label_list.append(label_array)

              #[[2k], [1k]]
        
        if undersampling or balance_dataset==False:
            images_per_class.append(ipp)
        else:
            images_per_class.append(images_number)

        classes += 1

    #offline augmentation
    if balance_dataset and undersampling==False:

      
         max=np.max((images_per_class)) #[4k,3k,2k,1k]

         for j in range(0, len(images_per_class)):  #[[4k], [4k], [4k], [4k]]
            if images_per_class[j] < max:
              diff=max - images_per_class[j] #how many images to generate

              image_array=image_list[j]   #[3k]
              label_array=label_list[j]   #[3k]

              new_image_array=[]
             

              #use ImageDataGenerator 
              offline_generator = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20, zoom_range=0.15,
                       	width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
	                       horizontal_flip=True, fill_mode="constant")


              offline_generator=offline_generator.flow(image_array, batch_size=1, seed = 2)

              #generate the reamining images respect the majority class, to balance the dataset
              generated_images=0
              while generated_images < diff:
                     
                  for i in range(0,len(offline_generator)):
                        if generated_images == diff:
                          break
                        batch= next(offline_generator)
                        # print(batch.shape)
                        #print(new_image_array.shape)
                        new_image_array.append(batch[0])
                        
                        label_array.append(j)

                      
                        generated_images += 1

            
     
              image_list[j]=np.append(image_list[j], new_image_array, axis=0)


         # image_list and label_list were of type [[...], [...]] for attack and bonafide classes
         # we need a final array of type [image1,image2,...] for images and [0,1,...] for labels

         new_image_list= np.empty((0, final_x, final_y, n_channels))
         new_label_list=[]


         for class_value_array in image_list:
           new_image_list = np.vstack((new_image_list,class_value_array))

         for class_value_array in label_list:
           new_label_list += class_value_array

         image_list = new_image_list
         label_list = new_label_list

         print(image_list.shape)
         print(len(label_list))
         
        # im_show(new_image_list[2]) # we can show up an image 
      
        
    #create the one-hot encoded vector: [0 1], [1 0]
    le = LabelEncoder()
    labels = le.fit_transform(label_list)
    labels = tf.keras.utils.to_categorical(labels, 2)

    if type(image_list) is np.ndarray:
      return image_list, labels, le

    return  np.array(image_list, dtype="float"), labels, le



read_from_np_array = True



## WE CAN SAVE NUMPY RESULTS AND REUSE THEM LATER ##

if read_from_np_array:
      (trainX, testX, trainY, testY) = pickle.loads(open(output_np_training_array, "rb").read())
      le = pickle.loads(open(save_labels, "rb").read())

## WE ARE GOING TO GET THE TRAIN AND VALIDATION DATASETS, AND WE SAVE THE NUMPY ARRAYS ##
else:
      
      trainX, trainY, label_encoder = get_images([output_bonifade_training_folder, output_attack_training_folder], undersampling=True)

     
      #will be ignored if we set split_randomly_training_and_validation variable to True
      testX, testY, _ = get_images([output_bonifade_validation_folder, output_attack_validation_folder], undersampling=True)


      #save model labels 
      f = open(save_labels, "wb")
      f.write(pickle.dumps(label_encoder))
      f.close()

      #save results
      pickle.dump((trainX, testX, trainY, testY), open(output_np_training_array, 'wb'))


 
print("Shape training: ", trainX.shape)
print("Shape validation: ", testX.shape)
# Out:
# Shape training:  (1638, 32, 32, 3)
# Shape validation:  (1638, 32, 32, 3)

# %% [markdown]
# ## Augmentation Online

# %%
augmentation_online=True



#the random seed for online augmentation
generator_seed=10

 
if augmentation_online:
		#online augmentation of training images
		aug_training = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20, zoom_range=0.15,
		 	    width_shift_range=0.1, height_shift_range=0.1, shear_range=0.15,
			 horizontal_flip=True, fill_mode="nearest")

		#aug_training = tf.keras.preprocessing.image.ImageDataGenerator()


		# output an endless Iterator of batches
		# shuffle images, so the first generated batch is from batch_size random training images

		train_generator=aug_training.flow(trainX, trainY, batch_size=batch_size, shuffle=True, seed=generator_seed)


		# will be equal to np.ceil(len(train(X))/batch_size)
		# notice: if len(trainX) / batch_size is a float value, the last batch will contain less images than batch_size value
		print("lenght training batches ", len(train_generator))
		print("lenght training data ", len(trainX))
		print("lenght validation data ", len(testX))

		# we could use also a validation_generator, without augment images
		# this "trick" could be done for set up a valdation batch size on model.fit().. then at the end of an epoch, each batch will be validated

		#aug_validation=ImageDataGenerator()
		#validation_generator=aug_validation.flow(testX, testY, batch_size=batch_size, shuffle=False, seed=1)
# Out:
# lenght training batches  103
# lenght training data  1638
# lenght validation data  1638

# %% [markdown]
# We can output the generator images organized in batches

# %%
# we generate batch_size images, beginning from the first batch
batchx, batchy = next(train_generator)
for i in range(batchx.shape[0]):
    fig, (ax1) = plt.subplots(1) 
    ax1.set_title('image')  
    ax1.imshow(batchx[i][:,:,0], cmap='gray')
    print("Label-%d:"%i, np.argmax(batchy[i]))


train_generator.reset() #once an epoch ends, this function will be called to reset data

# we generate exactly len(trainX) - batch_size images beginning from the first batch, since we have reset the train_generator on the line before
for i in range(0,len(train_generator) - 1):
 break # remove to see all training augmented images for an epoch
 batchx, batchy = next(train_generator)
 for i in range(batchx.shape[0]):
    fig, (ax1) = plt.subplots(1) 
    ax1.set_title('image')  
    ax1.imshow(batchx[i][:,:,0], cmap='gray')
    print("Label-%d:"%i, batchy[i][0])

# %% [markdown]
# ## OFFLINE AUGMENTATION (optional)

# %% [markdown]
# For each image in the training set, we're going to augment the image itself and we add it to the training. So if we have 2k images for the training, the final length of the dataset will be 4k.

# %%
augmentation_online=False

generator_seed=10
     

if not augmentation_online:


  to_augment=len(trainY) 

  #print(to_augment)
  # to fill tensors we inizialise them
  X = np.empty((to_augment, final_x, final_y, n_channels), dtype="float")

  L = np.empty((to_augment), dtype="int")

  #use ImageDataGenerator 
  offline_generator = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20, zoom_range=0.15,
		 	    width_shift_range=0.1, height_shift_range=0.1, shear_range=0.15,
			 horizontal_flip=True, fill_mode="nearest")


  offline_generator=offline_generator.flow(trainX, trainY, shuffle=True, batch_size=1, seed=generator_seed)

  #for all initial images
  for i in range(0,to_augment):
            batchx, batchy = next(offline_generator)
            X[i] = batchx[0]
            L[i] = np.argmax(batchy[0])
          
  
  labels = le.fit_transform(L)
  labels = tf.keras.utils.to_categorical(labels, 2)

  trainX = np.vstack((trainX, X))
  trainY = np.vstack((trainY, labels))


print("Shape training: ", trainX.shape)
print("Shape validation: ", testX.shape)
# Out:
# Shape training:  (3276, 32, 32, 3)
# Shape validation:  (1638, 32, 32, 3)

# %% [markdown]
# ## **Train the Model**
#
# We train the **model** and we save in a **CustomCallback** instance the average loss and accuracy for each training and validation batch. In this way, we can create a more defined training plot.

# %%
import torch, psutil


class MemoryUsage(tf.keras.callbacks.Callback):

   def __init__(self):
      # setting device on GPU if available, else CPU
      self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
      print('Using device for training:', self.device)
      self.max_RAM=[]
      self.max_GPU=[]

   def get_memory_usage(self):
      gpu_dict = tf.config.experimental.get_memory_info('GPU:0')
      tf.print('\n GPU memory details [current: {} gb, peak: {} gb]'.format(
          float(gpu_dict['current']) / (1024 ** 3), 
          float(gpu_dict['peak']) / (1024 ** 3)))
   
   def get_size(self, byte, suffix="GB"):
    factor = 1024
    
    for unit in ["", "K", "M", "GB", "T", "P"]:
        if byte < factor:
            return f"{byte:.2f} GB"
        byte /= factor

   def on_train_end(self, epoch, logs=None):
      i=np.argmax(self.max_RAM)
      self.get_memory_usage()
      print("MAX RAM USAGE: %s / %s (%s)" % (self.get_size(self.max_RAM[i][0]), self.get_size(self.max_RAM[i][1]), str(self.max_RAM[i][2]) + "%" ))
      


   
   def on_epoch_end(self,epoch,logs=None):
      svmem = psutil.virtual_memory()
      self.max_RAM.append((svmem.active, svmem.total, svmem.percent))
      #self.get_memory_usage()
      
      
      
      


# initialize the optimizer and model
print("[INFO] compiling model...")




#opt = tf.keras.optimizers.SGD(learning_rate=init_learning_rate, momentum = 0.5)
opt = tf.keras.optimizers.Adam(learning_rate=init_learning_rate)
#opt = tf.keras.optimizers.Adam(learning_rate=init_learning_rate)

#opt = tf.keras.optimizers.SGD(learning_rate=init_learning_rate, momentum = 0.5)
#opt = tf.keras.optimizers.Adam(learning_rate=init_learning_rate, decay=init_learning_rate/epochs)


#opt = tf.keras.optimizers.SGD(learning_rate=init_learning_rate, momentum = 0.99)
tf_seed()
model = LiveNet((final_y,final_x,n_channels))

callback_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=50)
memory_usage = MemoryUsage()


model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])  # same of binary_crossentropy in this case



import time
start_time = time.time()

#validation batch_size is equal to batch_size in this case (32)
#check https://github.com/keras-team/keras/blob/v2.9.0/keras/engine/training.py#L1099-L1472
if augmentation_online:
    H=model.fit(
      train_generator, 
      validation_data = (testX, testY), 
      callbacks = [memory_usage, callback_early_stopping],
      epochs= epochs)
else:
   
   H=model.fit(
      trainX, trainY, 
      batch_size = batch_size,
      shuffle=True,
      validation_data = (testX, testY), 
      callbacks = [memory_usage, callback_early_stopping],
      epochs= epochs)

print("TRAINING TIME")
print("--- %s seconds ---" % (time.time() - start_time))

import matplotlib.pyplot as plt

#print((history.epoch_batch_train_acc[0])) #show first epoch batches averaged values

print("[INFO] serializing network to '{}'...".format(save_model_h5))
model.save(save_model_h5, save_format="h5")


if not read_from_np_array:
   #save model labels 
      f = open(save_labels, "wb")
      f.write(pickle.dumps(label_encoder))
      f.close()


plt.style.use("ggplot")
plt.figure()
fig=plt.figure(figsize=(12,7))



new_epochs=len(H.history['loss'])
plt.plot(np.arange(0, new_epochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, new_epochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, new_epochs), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, new_epochs), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")


plt.savefig(save_training_metrics_plot)


# notice accuracy at the end of each epoch is the mean all over the batches, the same if we have more than 1 validation batch

#https://keras.io/guides/training_with_built_in_methods/
#https://keras.io/getting_started/faq/#why-is-my-training-loss-much-higher-than-my-testing-loss
#https://stackoverflow.com/questions/55097362/different-accuracy-by-fit-and-evaluate-in-keras-with-the-same-dataset

# the below code can give never seen images at each validation_step; more in general we divide validation dataset in batches
# see https://stackoverflow.com/questions/56991909/how-is-the-keras-accuracy-showed-in-progress-bar-calculated-from-which-inputs-i


#model.fit(train_generator,
 # steps_per_epoch=len(train_generator),
  #validation_data = validation_generator,
	#epochs=3)
# Out:
# [INFO] compiling model...
# Using device for training: cuda
# Epoch 1/30
# 103/103 [==============================] - 14s 19ms/step - loss: 0.8638 - accuracy: 0.6178 - val_loss: 1.1471 - val_accuracy: 0.5000
# Epoch 2/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.7837 - accuracy: 0.6545 - val_loss: 0.9534 - val_accuracy: 0.5153
# Epoch 3/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.7191 - accuracy: 0.6685 - val_loss: 0.7478 - val_accuracy: 0.6545
# Epoch 4/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.7221 - accuracy: 0.6612 - val_loss: 0.5147 - val_accuracy: 0.7234
# Epoch 5/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.6632 - accuracy: 0.7063 - val_loss: 0.4235 - val_accuracy: 0.7814
# Epoch 6/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.5900 - accuracy: 0.7222 - val_loss: 0.3895 - val_accuracy: 0.8156
# Epoch 7/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.5635 - accuracy: 0.7491 - val_loss: 0.3657 - val_accuracy: 0.8236
# Epoch 8/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.5420 - accuracy: 0.7662 - val_loss: 0.2815 - val_accuracy: 0.8907
# Epoch 9/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.5121 - accuracy: 0.7753 - val_loss: 0.3181 - val_accuracy: 0.8602
# Epoch 10/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.4853 - accuracy: 0.7985 - val_loss: 0.3711 - val_accuracy: 0.8516
# Epoch 11/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.4703 - accuracy: 0.8120 - val_loss: 0.3574 - val_accuracy: 0.8413
# Epoch 12/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.4399 - accuracy: 0.8217 - val_loss: 0.2149 - val_accuracy: 0.9200
# Epoch 13/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.3958 - accuracy: 0.8321 - val_loss: 0.2073 - val_accuracy: 0.9182
# Epoch 14/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.3823 - accuracy: 0.8321 - val_loss: 0.2612 - val_accuracy: 0.9029
# Epoch 15/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.3666 - accuracy: 0.8498 - val_loss: 0.3076 - val_accuracy: 0.8590
# Epoch 16/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.3450 - accuracy: 0.8510 - val_loss: 0.3102 - val_accuracy: 0.8810
# Epoch 17/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.3206 - accuracy: 0.8700 - val_loss: 0.1836 - val_accuracy: 0.9176
# Epoch 18/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.3236 - accuracy: 0.8675 - val_loss: 0.1961 - val_accuracy: 0.9274
# Epoch 19/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2966 - accuracy: 0.8785 - val_loss: 0.2603 - val_accuracy: 0.8822
# Epoch 20/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2874 - accuracy: 0.8767 - val_loss: 0.2119 - val_accuracy: 0.9371
# Epoch 21/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2878 - accuracy: 0.8834 - val_loss: 0.1684 - val_accuracy: 0.9451
# Epoch 22/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2944 - accuracy: 0.8834 - val_loss: 0.1649 - val_accuracy: 0.9426
# Epoch 23/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2814 - accuracy: 0.8901 - val_loss: 0.1390 - val_accuracy: 0.9457
# Epoch 24/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2484 - accuracy: 0.9011 - val_loss: 0.1331 - val_accuracy: 0.9505
# Epoch 25/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2545 - accuracy: 0.8956 - val_loss: 0.1424 - val_accuracy: 0.9469
# Epoch 26/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2337 - accuracy: 0.9048 - val_loss: 0.1423 - val_accuracy: 0.9426
# Epoch 27/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2538 - accuracy: 0.8938 - val_loss: 0.2954 - val_accuracy: 0.8608
# Epoch 28/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2392 - accuracy: 0.9023 - val_loss: 0.1682 - val_accuracy: 0.9310
# Epoch 29/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2645 - accuracy: 0.8968 - val_loss: 0.1426 - val_accuracy: 0.9469
# Epoch 30/30
# 103/103 [==============================] - 2s 16ms/step - loss: 0.2423 - accuracy: 0.9042 - val_loss: 0.1304 - val_accuracy: 0.9426
#
#  GPU memory details [current: 0.03360176086425781 gb, peak: 0.13324451446533203 gb]
# MAX RAM USAGE: 2.57 GB / 51.00 GB (5.7%)
# TRAINING TIME
# --- 63.45863747596741 seconds ---
# [INFO] serializing network to '/content/drive/MyDrive/liveness_project/model_MSSpoof.h5'...

# %% [markdown]
# ## Evaluation

# %%
#confusion matrix


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import itertools
from itertools import cycle
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size

model = tf.keras.models.load_model(save_model_h5)


y_score = model.predict(testX)

y_pred = np.argmax(y_score, axis = 1)
y_test_ = np.argmax(testY, axis = 1)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    def precision(index):
      return round(cm[index][index] / cm[:, index].sum(),2)
    
    def recall(index):
      return round(cm[index][index] /cm[index].sum(),2)
    
    def F1_score(index):
      p=precision(index)
      r=recall(index)
      return round((2 * p * r)/(p + r),2)
    
    plt.figure(figsize=(6, 6), dpi=80)

    im = plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, round(cm[i, j],2),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
   

    #### CREATE THE PRECISION / RECALL / F1_SCORE TABLE ####

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    fig, ax1 = plt.subplots(figsize=(10, 2 + 3 / 2.5))
    
    col_labels=["Bonafide", "Attacker"]
    row_labels=['Precision','Recall','F1 Score']
    row_func=[precision,recall,F1_score]
    table_vals=[]  

    row_colors = np.full(len(row_labels), 'linen')
    col_colors = np.full(len(col_labels), 'lavender')

    
    for i in range(0, len(row_labels)):

      row=[]

      for j in range(0, len(col_labels)):
         row.append(row_func[i](j))

      table_vals.append(row)
    

    # the rectangle is where I want to place the table
    table = plt.table(cellText=table_vals,
                  cellLoc='center',
                  rowColours=row_colors,
                  rowLabels=row_labels,
                  rowLoc='center',
                  colColours=col_colors,
                  colLabels=col_labels,
                  loc='center')
    table.scale(1, 2)
    ax1.axis('off')

    

class_names = {"Bonafide", "Attacker"}

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test_, y_pred)

# Plot non-normalized confusion matrix
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion Matrix')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-271738dbb64d> in <module>()
#       7 from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
#       8
# ----> 9 model = tf.keras.models.load_model(save_model_h5)
#      10
#      11
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     213             return hdf5_format.load_model_from_hdf5(
#     214                 tf.io.gfile.GFile(filepath_str, mode='rb'), custom_objects,
# --> 215                 compile)
#     216         elif h5py is not None and isinstance(filepath, h5py.File):
#     217           return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     185     model_config = json_utils.decode(model_config)
#     186     model = model_config_lib.model_from_config(model_config,
# --> 187                                                custom_objects=custom_objects)
#     188
#     189     # set weights
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/model_config.py in model_from_config(config, custom_objects)
#      50                     '`Sequential.from_config(config)`?')
#      51   from keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 52   return deserialize(config, custom_objects=custom_objects)
#      53
#      54
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/serialization.py in deserialize(config, custom_objects)
#     209       module_objects=LOCAL.ALL_OBJECTS,
#     210       custom_objects=custom_objects,
# --> 211       printable_module_name='layer')
#     212
#     213
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     681             custom_objects=dict(
#     682                 list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 683                 list(custom_objects.items())))
#     684       else:
#     685         with CustomObjectScope(custom_objects):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in from_config(cls, config, custom_objects)
#     707           'name', 'layers', 'input_layers', 'output_layers']):
#     708         input_tensors, output_tensors, created_layers = reconstruct_from_config(
# --> 709             config, custom_objects)
#     710         model = cls(
#     711             inputs=input_tensors,
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in reconstruct_from_config(config, custom_objects, created_layers)
#    1336         while layer_nodes:
#    1337           node_data = layer_nodes[0]
# -> 1338           if process_node(layer, node_data):
#    1339             layer_nodes.pop(0)
#    1340           else:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in process_node(layer, node_data)
#    1280         input_tensors = (
#    1281             base_layer_utils.unnest_if_single_tensor(input_tensors))
# -> 1282       output_tensors = layer(input_tensors, **kwargs)
#    1283
#    1284       # Update node index map.
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1031     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#    1032       return self._functional_construction_call(inputs, args, kwargs,
# -> 1033                                                 input_list)
#    1034
#    1035     # Maintains info about the `Layer.call` stack.
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1172       # Check input assumptions set after layer building, e.g. input shape.
#    1173       outputs = self._keras_tensor_symbolic_call(
# -> 1174           inputs, input_masks, args, kwargs)
#    1175
#    1176       if outputs is None:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     895       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     896     else:
# --> 897       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     898
#     899   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     938           # overridden).
#     939           # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 940           self._maybe_build(inputs)
#     941           inputs = self._maybe_cast_inputs(inputs)
#     942           outputs = call_fn(inputs, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2740         # operations.
#    2741         with tf_utils.maybe_init_scope(self):
# -> 2742           self.build(input_shapes)  # pylint:disable=not-callable
#    2743       # We must set also ensure that the layer is marked as built, and the build
#    2744       # shape is stored since user defined build functions may not be calling
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/convolutional.py in build(self, input_shape)
#     206         constraint=self.kernel_constraint,
#     207         trainable=True,
# --> 208         dtype=self.dtype)
#     209     if self.use_bias:
#     210       self.bias = self.add_weight(
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     692         synchronization=synchronization,
#     693         aggregation=aggregation,
# --> 694         caching_device=caching_device)
#     695     if regularizer is not None:
#     696       # TODO(fchollet): in the future, this should be handled at the
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     918         dtype=dtype,
#     919         initializer=initializer,
# --> 920         **kwargs_for_getter)
#     921
#     922     # If we set an initializer and the variable processed it, tracking will not
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     127       synchronization=synchronization,
#     128       aggregation=aggregation,
# --> 129       shape=variable_shape if variable_shape else None)
#     130
#     131
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     263   def __call__(cls, *args, **kwargs):
#     264     if cls is VariableV1:
# --> 265       return cls._variable_v1_call(*args, **kwargs)
#     266     elif cls is Variable:
#     267       return cls._variable_v2_call(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     223         synchronization=synchronization,
#     224         aggregation=aggregation,
# --> 225         shape=shape)
#     226
#     227   def _variable_v2_call(cls,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/variables.py in <lambda>(**kwargs)
#     201                         shape=None):
#     202     """Call on Variable class. Useful to force the signature."""
# --> 203     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     204     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     205       previous_getter = _make_getter(getter, previous_getter)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2719         synchronization=synchronization,
#    2720         aggregation=aggregation,
# -> 2721         shape=shape)
#    2722   else:
#    2723     return variables.RefVariable(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     267       return cls._variable_v2_call(*args, **kwargs)
#     268     else:
# --> 269       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     270
#     271
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1674           aggregation=aggregation,
#    1675           shape=shape,
# -> 1676           distribute_strategy=distribute_strategy)
#    1677
#    1678   def _init_from_args(self,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1809           with ops.name_scope("Initializer"), device_context_manager(None):
#    1810             if init_from_fn:
# -> 1811               initial_value = initial_value()
#    1812             if isinstance(initial_value, trackable.CheckpointInitialValue):
#    1813               self._maybe_initialize_trackable()
#
# /usr/local/lib/python3.7/dist-packages/keras/initializers/initializers_v2.py in __call__(self, shape, dtype, **kwargs)
#     533     else:
#     534       limit = math.sqrt(3.0 * scale)
# --> 535       return self._random_generator.random_uniform(shape, -limit, limit, dtype)
#     536
#     537   def get_config(self):
#
# /usr/local/lib/python3.7/dist-packages/keras/backend.py in random_uniform(self, shape, minval, maxval, dtype)
#    1920     return tf.random.uniform(
#    1921         shape=shape, minval=minval, maxval=maxval, dtype=dtype,
# -> 1922         seed=self.make_legacy_seed())
#    1923
#    1924   def truncated_normal(self, shape, mean=0., stddev=1., dtype=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     294     maxval = 1
#     295   with ops.name_scope(name, "random_uniform", [shape, minval, maxval]) as name:
# --> 296     shape = tensor_util.shape_tensor(shape)
#     297     # In case of [0,1) floating results, minval and maxval is unused. We do an
#     298     # `is` comparison here since this is cheaper than isinstance or  __eq__.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_util.py in shape_tensor(shape)
#    1077       # not convertible to Tensors because of mixed content.
#    1078       shape = tuple(map(tensor_shape.dimension_value, shape))
# -> 1079   return ops.convert_to_tensor(shape, dtype=dtype, name="shape")
#    1080
#    1081
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1693
#    1694     if ret is None:
# -> 1695       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1696
#    1697     if ret is NotImplemented:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#     344
#     345
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     266   """
#     267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 268                         allow_broadcast=True)
#     269
#     270
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       with trace.Trace("tf.constant"):
#     278         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
#     281   g = ops.get_default_graph()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      99     except AttributeError:
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# --> 101   ctx.ensure_initialized()
#     102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/context.py in ensure_initialized(self)
#     573         pywrap_tfe.TFE_ContextOptionsSetRunEagerOpAsFunction(
#     574             opts, self._run_eager_op_as_function)
# --> 575         context_handle = pywrap_tfe.TFE_NewContext(opts)
#     576       finally:
#     577         pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# KeyboardInterrupt:
